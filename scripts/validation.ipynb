# %%
"""
This script runs the bootstrap kfold validation experiments as used in
the publication.

Usage:
  validation.py [--interpro] [--pfam] [--mf] [--cc] [--bp]
             [--use_cache] [--induce] [--verbose] [--abs] [--top=T]
             [--model=M] [--n_jobs=J] [--n_splits=S] [--n_iterations=I]
             [--h_iterations=H] [--directory=DIR]
  validation.py -h | --help

Options:
  -h --help     Show this screen.
  --interpro    Use interpro domains in features.
  --pfam        Use Pfam domains in features.
  --mf          Use Molecular Function Gene Ontology in features.
  --cc          Use Cellular Compartment Gene Ontology in features.
  --bp          Use Biological Process Gene Ontology in features.
  --binary      Use binary feature encoding instead of ternary.
  --induce      Use ULCA inducer over Gene Ontology.
  --verbose     Print intermediate output for debugging.
  --use_cache   Use cached features if available.
  --abs         Take the absolute value of feature weights when computing top
                features.
  --top=T       Top T features for each label to log [default: 25]
  --model=M         A binary classifier from Scikit-Learn implementing fit,
                    predict and predict_proba [default: LogisticRegression]
  --n_jobs=J        Number of processes to run in parallel [default: 1]
  --n_splits=S      Number of cross-validation splits [default: 5]
  --h_iterations=H  Number of hyperparameter tuning
                    iterations per fold [default: 60]
  --n_iterations=I  Number of bootstrap iterations [default: 5]
  --directory=DIR   Output directory [default: ./results/]
"""

import json
import logging
import pandas as pd
import numpy as np
import scipy as sp
from itertools import product
from operator import itemgetter
from collections import Counter
from datetime import datetime
from docopt import docopt

from pyppi.base import parse_args, su_make_dir
from pyppi.data import load_network_from_path, load_ptm_labels
from pyppi.data import testing_network_path, training_network_path
from pyppi.data import get_term_description, ipr_name_map, pfam_name_map

from pyppi.models.binary_relevance import get_coefs, top_n_features
from pyppi.models import make_classifier, get_parameter_distribution_for_model
from pyppi.models import supported_estimators
from pyppi.model_selection.scoring import fdr_score, specificity
from pyppi.model_selection.sampling import IterativeStratifiedKFold

from pyppi.data_mining.features import AnnotationExtractor
from pyppi.data_mining.uniprot import UniProt, get_active_instance
from pyppi.data_mining.tools import xy_from_interaction_frame
from pyppi.data_mining.ontology import get_active_instance as load_godag

from sklearn.base import clone
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.pipeline import Pipeline
from sklearn.multiclass import OneVsRestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.metrics import (
    recall_score, make_scorer,
    label_ranking_average_precision_score,
    label_ranking_loss,
    confusion_matrix
)

logging.captureWarnings(False)
logging.basicConfig(
    format='[%(asctime)s] %(levelname)s: %(message)s',
    datefmt='%m-%d-%Y %I:%M:%S',
    level=logging.DEBUG,
)
logger = logging.getLogger(__name__)

args = {
    'n_jobs': 3,
    'n_splits': 5,
    'n_iterations': 2,
    'h_iterations': 3,
    'induce': True,
    'verbose': True,
    'use_binary': False,
    'abs': True,
    'top': 25,
    'selection': [
        UniProt.data_types().GO_MF.value,
        UniProt.data_types().GO_BP.value,
        UniProt.data_types().GO_CC.value,
        UniProt.data_types().INTERPRO.value,
        UniProt.data_types().PFAM.value
    ],
    'model': 'LogisticRegression',
    'use_cache': True,
    'directory': './results/'
}
n_jobs = args['n_jobs']
n_splits = args['n_splits']
n_iter = args['n_iterations']
induce = args['induce']
verbose = args['verbose']
selection = args['selection']
model = args['model']
use_feature_cache = args['use_cache']
direc = args['directory']
hyperparam_iter = args['h_iterations']
get_top_n = args['top']
abs_weights = args['abs']
use_binary = args]


# Set up the folder for each experiment run named after the current time
folder = datetime.now().strftime("val_%y-%m-%d_%H-%M")
direc = "{}/{}/".format(direc, folder)
su_make_dir(direc)
json.dump(
    args, fp=open("{}/settings.json".format(direc), 'w'),
    indent=4, sort_keys=True)

# %%
# Load all the training data, features etc.
# ------------------------------------------------------------------- #
logging.info("Loading training and testing data.")
ipr_map = ipr_name_map(short_names=False)
pfam_map = pfam_name_map()
go_dag = load_godag()
uniprot = get_active_instance(
    verbose=verbose,
    sprot_cache=False if use_feature_cache else True,
    trembl_cache=False if use_feature_cache else True
)
data_types = UniProt.data_types()
labels = load_ptm_labels()
annotation_ex = AnnotationExtractor(
    induce=induce,
    selection=selection,
    n_jobs=n_jobs,
    verbose=verbose,
    cache=use_feature_cache,
    backend='threading'
)
training = load_network_from_path(training_network_path)
testing = load_network_from_path(testing_network_path)
# Out:
# [11-17-2017 01:49:07] INFO: Loading training and testing data.
# First time loading on GO-DAG instance. Make take a few moments
# load obo file C:\Users\Daniel\.pyppi\go.obo
# C:\Users\Daniel\.pyppi\go.obo: fmt(1.2) rel(2017-07-14) 48,971 GO Terms
# First time loading on UniProt instance. Make take a few moments
# Warning: Loading dat files, may take a few minutes.

# %%
# Get the features into X, and multilabel y indicator format
# -------------------------------------------------------------------- #
logging.info("Preparing training and testing data.")
mlb = MultiLabelBinarizer(classes=labels, sparse_output=False)
X_train_ppis, y_train = xy_from_interaction_frame(training)
X_test_ppis, y_test = xy_from_interaction_frame(testing)
mlb.fit(y_train)

logging.info("Computing class distributions.")
json.dump(
    Counter([l for ls in y_train for l in ls]),
    fp=open("{}/training_distribution.json".format(direc), 'w'),
    indent=4, sort_keys=True
)
json.dump(
    Counter([l for ls in y_test for l in ls]),
    fp=open("{}/testing_distribution.json".format(direc), 'w'),
    indent=4, sort_keys=True
)

X_train = annotation_ex.transform(X_train_ppis)
X_test = annotation_ex.transform(X_test_ppis)
y_train = mlb.transform(y_train)
y_test = mlb.transform(y_test)
# Out:
# [11-17-2017 01:49:58] INFO: Preparing training and testing data.
# [11-17-2017 01:49:58] INFO: Computing class distributions.

# %%
# These take up around ~5GB so it's best to delete them from memory
# -------------------------------------------------------------------- #
del annotation_ex
del uniprot

# %%
# Set up the numpy arrays and dictionarys for statistics etc
# -------------------------------------------------------------------- #
logging.info("Setting up preliminaries and the statistics arrays")
logging.info("Found classes {}".format(', '.join(mlb.classes)))
n_classes = len(mlb.classes)
seeds = range(n_iter)
top_features = {
    l: {
        i: {
            j: [] for j in range(n_splits)
        } for i in range(n_iter)
    } for l in mlb.classes
}
params = get_parameter_distribution_for_model(model)

binary_scoring_funcs = [
    ('Binary F1', f1_score),
    ('Precision', precision_score),
    ('Recall', recall_score),
    ('Specificity', specificity),
    ('FDR', fdr_score)
]
multilabel_scoring_funcs = [
    ('Label Ranking Loss', label_ranking_loss),
    ('Label Ranking Average Precision',
        label_ranking_average_precision_score),
    ('Macro (weighted) F1', f1_score),
    ('Macro (un-weighted) F1', f1_score)
]
n_scorers = len(binary_scoring_funcs)
n_ml_scorers = len(multilabel_scoring_funcs)

# 2: position 0 is for validation, position 1 is for testing
binary_statistics = np.zeros((n_classes, 2, n_scorers, n_iter, n_splits))
multilabel_statistics = np.zeros((2, n_ml_scorers, n_iter, n_splits))
# Out:
# [11-10-2017 11:05:24] INFO: Setting up preliminaries and the statistics arrays
# [11-10-2017 11:05:24] INFO: Found classes phosphorylation, acetylation, binding/association, deacetylation, ubiquitination, state-change, myristoylation, prenylation, sumoylation, dephosphorylation, glycosylation, inhibition, activation, methylation, dissociation, carboxylation, sulfation, proteolytic-cleavage

# %%
# Begin the main show!
# ------------------------------------------------------------------- #
for bs_iter in range(n_iter):
    logging.info("Fitting bootstrap iteration {}.".format(bs_iter + 1))
    cv = IterativeStratifiedKFold(n_splits=n_splits, random_state=seeds[bs_iter])
    
    for fold_iter, (train_idx, validation_idx) in enumerate(cv.split(X_train, y_train)):
        logging.info("Fitting fold iteration {}.".format(fold_iter + 1))
        y_valid_f_pred = []
        y_test_f_pred = []
        y_valid_f_proba = []
        y_test_f_proba = []
        
        for label_idx, label in enumerate(mlb.classes):
            logging.info("Fitting label {}.".format(label))
            
            # Prepare all training and testing data
            logging.info("Preparing data.")
            vectorizer = CountVectorizer(binary=True if use_binary else False)
            vectorizer.fit(X_train[train_idx])

            X_train_l = vectorizer.transform(X_train[train_idx])
            y_train_l = y_train[train_idx, label_idx]

            X_valid_l = vectorizer.transform(X_train[validation_idx])
            y_valid_l = y_train[validation_idx, label_idx]

            X_test_l = vectorizer.transform(X_test)
            y_test_l = y_test[:, label_idx]
            
            # Build and fit classifier
            logging.info("Fitting classifier.")
            base_est = make_classifier(
                algorithm=model, 
                random_state=0
            )
            clf = RandomizedSearchCV(
                estimator=base_est,
                scoring='f1', 
                error_score=0,
                cv=3,
                n_iter=hyperparam_iter, 
                n_jobs=n_jobs, 
                refit=True, 
                random_state=0, 
                param_distributions=params,
            )
            try:
                clf.fit(X_train_l, y_train_l)
            except TypeError:
                logger.info("Error fitting sparse input. Converting to dense input.")
                X_train_l = X_train_l.todense()
                X_valid_l = X_valid_l.todense()
                X_test_l = X_test_l.todense()
                clf.fit(X_train_l, y_train_l)
            
            # Validation scores in binary and probability format
            logging.info("Making predictions on validation data.")
            y_valid_l_pred = clf.predict(X_valid_l)
            y_valid_l_proba = clf.predict_proba(X_valid_l)

            # Held-out testing scores in binary and probability format
            logging.info("Making predictions on testing data.")
            y_test_l_pred = clf.predict(X_test_l)
            y_test_l_proba = clf.predict_proba(X_test_l)

            # Store these per label results in a list which we will
            # later use to stack into a multi-label array.
            logging.info("Storing validation predictions.")
            y_valid_f_pred.append([[x] for x in y_valid_l_pred])
            y_valid_f_proba.append([[x[1]] for x in y_valid_l_proba])

            logging.info("Storing testing predictions.")
            y_test_f_pred.append([[x] for x in y_test_l_pred])
            y_test_f_proba.append([[x[1]] for x in y_test_l_proba])
            
            # Perform scoring on the validation set and the external testing set.
             
            for func_idx, (func_name, func) in enumerate(binary_scoring_funcs):
                if func_name in ['Specificity', 'FDR']:
                    scores_v = func(y_valid_l, y_valid_l_pred)
                    scores_t = func(y_test_l, y_test_l_pred)
                else:
                    scores_v = func(y_valid_l, y_valid_l_pred, average='binary')
                    scores_t = func(y_test_l, y_test_l_pred, average='binary')
                binary_statistics[label_idx, 0, func_idx, bs_iter, fold_iter] = scores_v
                binary_statistics[label_idx, 1, func_idx, bs_iter, fold_iter] = scores_t
                
            logging.info("Computing top label features for fold.")
            # Get the top 20 features for this labels's run.
            top_n = top_n_features(
                clf=clf,
                go_dag=go_dag,
                ipr_map=ipr_map,
                pfam_map=pfam_map,
                n=get_top_n,
                absolute=abs_weights,
                vectorizer=vectorizer
            )
            top_features[label][bs_iter][fold_iter].extend(top_n)
        
        logging.info("Computing fold mult-label performance.")
        # True scores in multi-label indicator format
        y_valid_f = y_train[validation_idx]
        y_test_f = y_test

        # Validation scores in multi-label indicator format
        y_valid_f_pred = np.hstack(y_valid_f_pred)
        y_valid_f_proba = np.hstack(y_valid_f_proba)

        # Testing scores in multi-label probability format
        y_test_f_pred = np.hstack(y_test_f_pred)
        y_test_f_proba = np.hstack(y_test_f_proba)
           
        for func_idx, (func_name, func) in enumerate(multilabel_scoring_funcs):
            if func_name == 'Macro (weighted) F1':
                scores_v = func(y_valid_f, y_valid_f_pred, average='weighted')
                scores_t = func(y_test_f, y_test_f_pred, average='weighted')
            elif func_name == 'Macro (un-weighted) F1':
                scores_v = func(y_valid_f, y_valid_f_pred, average='macro')
                scores_t = func(y_test_f, y_test_f_pred, average='macro')
            elif func_name == 'Label Ranking Average Precision':
                scores_v = func(y_valid_f, y_valid_f_proba)
                scores_t = func(y_test_f, y_test_f_proba)
            else:
                scores_v = func(y_valid_f, y_valid_f_pred)
                scores_t = func(y_test_f, y_test_f_pred)
                
            multilabel_statistics[0, func_idx, bs_iter, fold_iter] = scores_v
            multilabel_statistics[1, func_idx, bs_iter, fold_iter] = scores_t
# Out:
# [11-10-2017 11:05:25] INFO: Fitting bootstrap iteration 1.
# [11-10-2017 11:05:27] INFO: Fitting fold iteration 1.
# [11-10-2017 11:05:27] INFO: Fitting label phosphorylation.
# [11-10-2017 11:05:27] INFO: Preparing data.
# [11-10-2017 11:05:35] INFO: Fitting classifier.
# [11-10-2017 11:06:26] INFO: Making predictions on validation data.
# [11-10-2017 11:06:26] INFO: Making predictions on testing data.
# [11-10-2017 11:06:26] INFO: Storing validation predictions.
# [11-10-2017 11:06:26] INFO: Storing testing predictions.
# [11-10-2017 11:06:26] INFO: Computing top label features for fold.
# [11-10-2017 11:06:26] INFO: Fitting label acetylation.
# [11-10-2017 11:06:26] INFO: Preparing data.
# [11-10-2017 11:06:34] INFO: Fitting classifier.
# [11-10-2017 11:06:43] INFO: Making predictions on validation data.
# [11-10-2017 11:06:43] INFO: Making predictions on testing data.
# [11-10-2017 11:06:43] INFO: Storing validation predictions.
# [11-10-2017 11:06:43] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:06:43] INFO: Computing top label features for fold.
# [11-10-2017 11:06:43] INFO: Fitting label binding/association.
# [11-10-2017 11:06:43] INFO: Preparing data.
# [11-10-2017 11:06:51] INFO: Fitting classifier.
# [11-10-2017 11:07:17] INFO: Making predictions on validation data.
# [11-10-2017 11:07:17] INFO: Making predictions on testing data.
# [11-10-2017 11:07:17] INFO: Storing validation predictions.
# [11-10-2017 11:07:17] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:07:17] INFO: Computing top label features for fold.
# [11-10-2017 11:07:17] INFO: Fitting label deacetylation.
# [11-10-2017 11:07:17] INFO: Preparing data.
# [11-10-2017 11:07:25] INFO: Fitting classifier.
# [11-10-2017 11:07:31] INFO: Making predictions on validation data.
# [11-10-2017 11:07:31] INFO: Making predictions on testing data.
# [11-10-2017 11:07:31] INFO: Storing validation predictions.
# [11-10-2017 11:07:31] INFO: Storing testing predictions.
# [11-10-2017 11:07:31] INFO: Computing top label features for fold.
# [11-10-2017 11:07:31] INFO: Fitting label ubiquitination.
# [11-10-2017 11:07:31] INFO: Preparing data.
# [11-10-2017 11:07:39] INFO: Fitting classifier.
# [11-10-2017 11:07:48] INFO: Making predictions on validation data.
# [11-10-2017 11:07:48] INFO: Making predictions on testing data.
# [11-10-2017 11:07:48] INFO: Storing validation predictions.
# [11-10-2017 11:07:48] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:07:48] INFO: Computing top label features for fold.
# [11-10-2017 11:07:48] INFO: Fitting label state-change.
# [11-10-2017 11:07:48] INFO: Preparing data.
# [11-10-2017 11:07:56] INFO: Fitting classifier.
# [11-10-2017 11:08:06] INFO: Making predictions on validation data.
# [11-10-2017 11:08:06] INFO: Making predictions on testing data.
# [11-10-2017 11:08:06] INFO: Storing validation predictions.
# [11-10-2017 11:08:06] INFO: Storing testing predictions.
# [11-10-2017 11:08:06] INFO: Computing top label features for fold.
# [11-10-2017 11:08:06] INFO: Fitting label myristoylation.
# [11-10-2017 11:08:06] INFO: Preparing data.
# [11-10-2017 11:08:13] INFO: Fitting classifier.
# [11-10-2017 11:08:19] INFO: Making predictions on validation data.
# [11-10-2017 11:08:19] INFO: Making predictions on testing data.
# [11-10-2017 11:08:19] INFO: Storing validation predictions.
# [11-10-2017 11:08:19] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:08:19] INFO: Computing top label features for fold.
# [11-10-2017 11:08:19] INFO: Fitting label prenylation.
# [11-10-2017 11:08:19] INFO: Preparing data.
# [11-10-2017 11:08:27] INFO: Fitting classifier.
# [11-10-2017 11:08:32] INFO: Making predictions on validation data.
# [11-10-2017 11:08:32] INFO: Making predictions on testing data.
# [11-10-2017 11:08:32] INFO: Storing validation predictions.
# [11-10-2017 11:08:32] INFO: Storing testing predictions.
# [11-10-2017 11:08:33] INFO: Computing top label features for fold.
# [11-10-2017 11:08:33] INFO: Fitting label sumoylation.
# [11-10-2017 11:08:33] INFO: Preparing data.
# [11-10-2017 11:08:40] INFO: Fitting classifier.
# [11-10-2017 11:08:48] INFO: Making predictions on validation data.
# [11-10-2017 11:08:48] INFO: Making predictions on testing data.
# [11-10-2017 11:08:48] INFO: Storing validation predictions.
# [11-10-2017 11:08:48] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:08:48] INFO: Computing top label features for fold.
# [11-10-2017 11:08:48] INFO: Fitting label dephosphorylation.
# [11-10-2017 11:08:48] INFO: Preparing data.
# [11-10-2017 11:08:55] INFO: Fitting classifier.
# [11-10-2017 11:09:08] INFO: Making predictions on validation data.
# [11-10-2017 11:09:08] INFO: Making predictions on testing data.
# [11-10-2017 11:09:08] INFO: Storing validation predictions.
# [11-10-2017 11:09:08] INFO: Storing testing predictions.
# [11-10-2017 11:09:08] INFO: Computing top label features for fold.
# [11-10-2017 11:09:08] INFO: Fitting label glycosylation.
# [11-10-2017 11:09:08] INFO: Preparing data.
# [11-10-2017 11:09:15] INFO: Fitting classifier.
# [11-10-2017 11:09:22] INFO: Making predictions on validation data.
# [11-10-2017 11:09:22] INFO: Making predictions on testing data.
# [11-10-2017 11:09:22] INFO: Storing validation predictions.
# [11-10-2017 11:09:22] INFO: Storing testing predictions.
# [11-10-2017 11:09:22] INFO: Computing top label features for fold.
# [11-10-2017 11:09:22] INFO: Fitting label inhibition.
# [11-10-2017 11:09:22] INFO: Preparing data.
# [11-10-2017 11:09:29] INFO: Fitting classifier.
# [11-10-2017 11:10:00] INFO: Making predictions on validation data.
# [11-10-2017 11:10:00] INFO: Making predictions on testing data.
# [11-10-2017 11:10:00] INFO: Storing validation predictions.
# [11-10-2017 11:10:00] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:10:00] INFO: Computing top label features for fold.
# [11-10-2017 11:10:00] INFO: Fitting label activation.
# [11-10-2017 11:10:00] INFO: Preparing data.
# [11-10-2017 11:10:08] INFO: Fitting classifier.
# [11-10-2017 11:10:46] INFO: Making predictions on validation data.
# [11-10-2017 11:10:46] INFO: Making predictions on testing data.
# [11-10-2017 11:10:46] INFO: Storing validation predictions.
# [11-10-2017 11:10:46] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:10:46] INFO: Computing top label features for fold.
# [11-10-2017 11:10:46] INFO: Fitting label methylation.
# [11-10-2017 11:10:46] INFO: Preparing data.
# [11-10-2017 11:10:53] INFO: Fitting classifier.
# [11-10-2017 11:11:00] INFO: Making predictions on validation data.
# [11-10-2017 11:11:00] INFO: Making predictions on testing data.
# [11-10-2017 11:11:00] INFO: Storing validation predictions.
# [11-10-2017 11:11:00] INFO: Storing testing predictions.
# [11-10-2017 11:11:00] INFO: Computing top label features for fold.
# [11-10-2017 11:11:00] INFO: Fitting label dissociation.
# [11-10-2017 11:11:00] INFO: Preparing data.
# [11-10-2017 11:11:08] INFO: Fitting classifier.
# [11-10-2017 11:11:20] INFO: Making predictions on validation data.
# [11-10-2017 11:11:20] INFO: Making predictions on testing data.
# [11-10-2017 11:11:20] INFO: Storing validation predictions.
# [11-10-2017 11:11:20] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:11:20] INFO: Computing top label features for fold.
# [11-10-2017 11:11:20] INFO: Fitting label carboxylation.
# [11-10-2017 11:11:20] INFO: Preparing data.
# [11-10-2017 11:11:28] INFO: Fitting classifier.
# [11-10-2017 11:11:33] INFO: Making predictions on validation data.
# [11-10-2017 11:11:33] INFO: Making predictions on testing data.
# [11-10-2017 11:11:33] INFO: Storing validation predictions.
# [11-10-2017 11:11:33] INFO: Storing testing predictions.
# [11-10-2017 11:11:33] INFO: Computing top label features for fold.
# [11-10-2017 11:11:33] INFO: Fitting label sulfation.
# [11-10-2017 11:11:33] INFO: Preparing data.
# [11-10-2017 11:11:40] INFO: Fitting classifier.
# [11-10-2017 11:11:46] INFO: Making predictions on validation data.
# [11-10-2017 11:11:46] INFO: Making predictions on testing data.
# [11-10-2017 11:11:46] INFO: Storing validation predictions.
# [11-10-2017 11:11:46] INFO: Storing testing predictions.
# [11-10-2017 11:11:46] INFO: Computing top label features for fold.
# [11-10-2017 11:11:46] INFO: Fitting label proteolytic-cleavage.
# [11-10-2017 11:11:46] INFO: Preparing data.
# [11-10-2017 11:11:53] INFO: Fitting classifier.
# [11-10-2017 11:12:06] INFO: Making predictions on validation data.
# [11-10-2017 11:12:06] INFO: Making predictions on testing data.
# [11-10-2017 11:12:06] INFO: Storing validation predictions.
# [11-10-2017 11:12:06] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:12:06] INFO: Computing top label features for fold.
# [11-10-2017 11:12:06] INFO: Computing fold mult-label performance.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:12:09] INFO: Fitting fold iteration 2.
# [11-10-2017 11:12:09] INFO: Fitting label phosphorylation.
# [11-10-2017 11:12:09] INFO: Preparing data.
# [11-10-2017 11:12:16] INFO: Fitting classifier.
# [11-10-2017 11:12:55] INFO: Making predictions on validation data.
# [11-10-2017 11:12:55] INFO: Making predictions on testing data.
# [11-10-2017 11:12:55] INFO: Storing validation predictions.
# [11-10-2017 11:12:55] INFO: Storing testing predictions.
# [11-10-2017 11:12:55] INFO: Computing top label features for fold.
# [11-10-2017 11:12:55] INFO: Fitting label acetylation.
# [11-10-2017 11:12:55] INFO: Preparing data.
# [11-10-2017 11:13:02] INFO: Fitting classifier.
# [11-10-2017 11:13:12] INFO: Making predictions on validation data.
# [11-10-2017 11:13:12] INFO: Making predictions on testing data.
# [11-10-2017 11:13:12] INFO: Storing validation predictions.
# [11-10-2017 11:13:12] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:13:12] INFO: Computing top label features for fold.
# [11-10-2017 11:13:12] INFO: Fitting label binding/association.
# [11-10-2017 11:13:12] INFO: Preparing data.
# [11-10-2017 11:13:20] INFO: Fitting classifier.
# [11-10-2017 11:13:47] INFO: Making predictions on validation data.
# [11-10-2017 11:13:47] INFO: Making predictions on testing data.
# [11-10-2017 11:13:47] INFO: Storing validation predictions.
# [11-10-2017 11:13:47] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:13:47] INFO: Computing top label features for fold.
# [11-10-2017 11:13:47] INFO: Fitting label deacetylation.
# [11-10-2017 11:13:47] INFO: Preparing data.
# [11-10-2017 11:13:54] INFO: Fitting classifier.
# [11-10-2017 11:14:01] INFO: Making predictions on validation data.
# [11-10-2017 11:14:01] INFO: Making predictions on testing data.
# [11-10-2017 11:14:01] INFO: Storing validation predictions.
# [11-10-2017 11:14:01] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [11-10-2017 11:14:01] INFO: Computing top label features for fold.
# [11-10-2017 11:14:01] INFO: Fitting label ubiquitination.
# [11-10-2017 11:14:01] INFO: Preparing data.
# [11-10-2017 11:14:08] INFO: Fitting classifier.
# [11-10-2017 11:14:18] INFO: Making predictions on validation data.
# [11-10-2017 11:14:18] INFO: Making predictions on testing data.
# [11-10-2017 11:14:18] INFO: Storing validation predictions.
# [11-10-2017 11:14:18] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:14:18] INFO: Computing top label features for fold.
# [11-10-2017 11:14:18] INFO: Fitting label state-change.
# [11-10-2017 11:14:18] INFO: Preparing data.
# [11-10-2017 11:14:25] INFO: Fitting classifier.
# [11-10-2017 11:14:33] INFO: Making predictions on validation data.
# [11-10-2017 11:14:33] INFO: Making predictions on testing data.
# [11-10-2017 11:14:33] INFO: Storing validation predictions.
# [11-10-2017 11:14:33] INFO: Storing testing predictions.
# [11-10-2017 11:14:33] INFO: Computing top label features for fold.
# [11-10-2017 11:14:33] INFO: Fitting label myristoylation.
# [11-10-2017 11:14:33] INFO: Preparing data.
# [11-10-2017 11:14:40] INFO: Fitting classifier.
# [11-10-2017 11:14:46] INFO: Making predictions on validation data.
# [11-10-2017 11:14:46] INFO: Making predictions on testing data.
# [11-10-2017 11:14:46] INFO: Storing validation predictions.
# [11-10-2017 11:14:46] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:14:46] INFO: Computing top label features for fold.
# [11-10-2017 11:14:46] INFO: Fitting label prenylation.
# [11-10-2017 11:14:46] INFO: Preparing data.
# [11-10-2017 11:14:53] INFO: Fitting classifier.
# [11-10-2017 11:14:59] INFO: Making predictions on validation data.
# [11-10-2017 11:14:59] INFO: Making predictions on testing data.
# [11-10-2017 11:14:59] INFO: Storing validation predictions.
# [11-10-2017 11:14:59] INFO: Storing testing predictions.
# [11-10-2017 11:14:59] INFO: Computing top label features for fold.
# [11-10-2017 11:15:00] INFO: Fitting label sumoylation.
# [11-10-2017 11:15:00] INFO: Preparing data.
# [11-10-2017 11:15:07] INFO: Fitting classifier.
# [11-10-2017 11:15:15] INFO: Making predictions on validation data.
# [11-10-2017 11:15:15] INFO: Making predictions on testing data.
# [11-10-2017 11:15:15] INFO: Storing validation predictions.
# [11-10-2017 11:15:15] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:15:15] INFO: Computing top label features for fold.
# [11-10-2017 11:15:15] INFO: Fitting label dephosphorylation.
# [11-10-2017 11:15:15] INFO: Preparing data.
# [11-10-2017 11:15:23] INFO: Fitting classifier.
# [11-10-2017 11:15:34] INFO: Making predictions on validation data.
# [11-10-2017 11:15:34] INFO: Making predictions on testing data.
# [11-10-2017 11:15:34] INFO: Storing validation predictions.
# [11-10-2017 11:15:34] INFO: Storing testing predictions.
# [11-10-2017 11:15:34] INFO: Computing top label features for fold.
# [11-10-2017 11:15:34] INFO: Fitting label glycosylation.
# [11-10-2017 11:15:34] INFO: Preparing data.
# [11-10-2017 11:15:42] INFO: Fitting classifier.
# [11-10-2017 11:15:48] INFO: Making predictions on validation data.
# [11-10-2017 11:15:48] INFO: Making predictions on testing data.
# [11-10-2017 11:15:48] INFO: Storing validation predictions.
# [11-10-2017 11:15:48] INFO: Storing testing predictions.
# [11-10-2017 11:15:48] INFO: Computing top label features for fold.
# [11-10-2017 11:15:48] INFO: Fitting label inhibition.
# [11-10-2017 11:15:48] INFO: Preparing data.
# [11-10-2017 11:15:55] INFO: Fitting classifier.
# [11-10-2017 11:16:30] INFO: Making predictions on validation data.
# [11-10-2017 11:16:30] INFO: Making predictions on testing data.
# [11-10-2017 11:16:30] INFO: Storing validation predictions.
# [11-10-2017 11:16:30] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:16:30] INFO: Computing top label features for fold.
# [11-10-2017 11:16:30] INFO: Fitting label activation.
# [11-10-2017 11:16:30] INFO: Preparing data.
# [11-10-2017 11:16:38] INFO: Fitting classifier.
# [11-10-2017 11:17:19] INFO: Making predictions on validation data.
# [11-10-2017 11:17:19] INFO: Making predictions on testing data.
# [11-10-2017 11:17:19] INFO: Storing validation predictions.
# [11-10-2017 11:17:19] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:17:19] INFO: Computing top label features for fold.
# [11-10-2017 11:17:19] INFO: Fitting label methylation.
# [11-10-2017 11:17:19] INFO: Preparing data.
# [11-10-2017 11:17:27] INFO: Fitting classifier.
# [11-10-2017 11:17:34] INFO: Making predictions on validation data.
# [11-10-2017 11:17:34] INFO: Making predictions on testing data.
# [11-10-2017 11:17:34] INFO: Storing validation predictions.
# [11-10-2017 11:17:34] INFO: Storing testing predictions.
# [11-10-2017 11:17:34] INFO: Computing top label features for fold.
# [11-10-2017 11:17:34] INFO: Fitting label dissociation.
# [11-10-2017 11:17:34] INFO: Preparing data.
# [11-10-2017 11:17:42] INFO: Fitting classifier.
# [11-10-2017 11:17:56] INFO: Making predictions on validation data.
# [11-10-2017 11:17:56] INFO: Making predictions on testing data.
# [11-10-2017 11:17:56] INFO: Storing validation predictions.
# [11-10-2017 11:17:56] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:17:56] INFO: Computing top label features for fold.
# [11-10-2017 11:17:56] INFO: Fitting label carboxylation.
# [11-10-2017 11:17:56] INFO: Preparing data.
# [11-10-2017 11:18:04] INFO: Fitting classifier.
# [11-10-2017 11:18:09] INFO: Making predictions on validation data.
# [11-10-2017 11:18:09] INFO: Making predictions on testing data.
# [11-10-2017 11:18:09] INFO: Storing validation predictions.
# [11-10-2017 11:18:09] INFO: Storing testing predictions.
# [11-10-2017 11:18:09] INFO: Computing top label features for fold.
# [11-10-2017 11:18:09] INFO: Fitting label sulfation.
# [11-10-2017 11:18:09] INFO: Preparing data.
# [11-10-2017 11:18:17] INFO: Fitting classifier.
# [11-10-2017 11:18:22] INFO: Making predictions on validation data.
# [11-10-2017 11:18:22] INFO: Making predictions on testing data.
# [11-10-2017 11:18:22] INFO: Storing validation predictions.
# [11-10-2017 11:18:22] INFO: Storing testing predictions.
# [11-10-2017 11:18:22] INFO: Computing top label features for fold.
# [11-10-2017 11:18:23] INFO: Fitting label proteolytic-cleavage.
# [11-10-2017 11:18:23] INFO: Preparing data.
# [11-10-2017 11:18:30] INFO: Fitting classifier.
# [11-10-2017 11:18:43] INFO: Making predictions on validation data.
# [11-10-2017 11:18:43] INFO: Making predictions on testing data.
# [11-10-2017 11:18:43] INFO: Storing validation predictions.
# [11-10-2017 11:18:43] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:18:43] INFO: Computing top label features for fold.
# [11-10-2017 11:18:43] INFO: Computing fold mult-label performance.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:18:45] INFO: Fitting fold iteration 3.
# [11-10-2017 11:18:45] INFO: Fitting label phosphorylation.
# [11-10-2017 11:18:45] INFO: Preparing data.
# [11-10-2017 11:18:53] INFO: Fitting classifier.
# [11-10-2017 11:19:28] INFO: Making predictions on validation data.
# [11-10-2017 11:19:28] INFO: Making predictions on testing data.
# [11-10-2017 11:19:28] INFO: Storing validation predictions.
# [11-10-2017 11:19:28] INFO: Storing testing predictions.
# [11-10-2017 11:19:28] INFO: Computing top label features for fold.
# [11-10-2017 11:19:28] INFO: Fitting label acetylation.
# [11-10-2017 11:19:28] INFO: Preparing data.
# [11-10-2017 11:19:35] INFO: Fitting classifier.
# [11-10-2017 11:19:45] INFO: Making predictions on validation data.
# [11-10-2017 11:19:45] INFO: Making predictions on testing data.
# [11-10-2017 11:19:45] INFO: Storing validation predictions.
# [11-10-2017 11:19:45] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:19:45] INFO: Computing top label features for fold.
# [11-10-2017 11:19:45] INFO: Fitting label binding/association.
# [11-10-2017 11:19:45] INFO: Preparing data.
# [11-10-2017 11:19:52] INFO: Fitting classifier.
# [11-10-2017 11:20:27] INFO: Making predictions on validation data.
# [11-10-2017 11:20:27] INFO: Making predictions on testing data.
# [11-10-2017 11:20:27] INFO: Storing validation predictions.
# [11-10-2017 11:20:27] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:20:27] INFO: Computing top label features for fold.
# [11-10-2017 11:20:27] INFO: Fitting label deacetylation.
# [11-10-2017 11:20:27] INFO: Preparing data.
# [11-10-2017 11:20:34] INFO: Fitting classifier.
# [11-10-2017 11:20:41] INFO: Making predictions on validation data.
# [11-10-2017 11:20:41] INFO: Making predictions on testing data.
# [11-10-2017 11:20:41] INFO: Storing validation predictions.
# [11-10-2017 11:20:41] INFO: Storing testing predictions.
# [11-10-2017 11:20:41] INFO: Computing top label features for fold.
# [11-10-2017 11:20:41] INFO: Fitting label ubiquitination.
# [11-10-2017 11:20:41] INFO: Preparing data.
# [11-10-2017 11:20:48] INFO: Fitting classifier.
# [11-10-2017 11:21:01] INFO: Making predictions on validation data.
# [11-10-2017 11:21:01] INFO: Making predictions on testing data.
# [11-10-2017 11:21:01] INFO: Storing validation predictions.
# [11-10-2017 11:21:01] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:21:01] INFO: Computing top label features for fold.
# [11-10-2017 11:21:01] INFO: Fitting label state-change.
# [11-10-2017 11:21:01] INFO: Preparing data.
# [11-10-2017 11:21:08] INFO: Fitting classifier.
# [11-10-2017 11:21:15] INFO: Making predictions on validation data.
# [11-10-2017 11:21:15] INFO: Making predictions on testing data.
# [11-10-2017 11:21:15] INFO: Storing validation predictions.
# [11-10-2017 11:21:15] INFO: Storing testing predictions.
# [11-10-2017 11:21:15] INFO: Computing top label features for fold.
# [11-10-2017 11:21:16] INFO: Fitting label myristoylation.
# [11-10-2017 11:21:16] INFO: Preparing data.
# [11-10-2017 11:21:23] INFO: Fitting classifier.
# [11-10-2017 11:21:28] INFO: Making predictions on validation data.
# [11-10-2017 11:21:28] INFO: Making predictions on testing data.
# [11-10-2017 11:21:28] INFO: Storing validation predictions.
# [11-10-2017 11:21:28] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:21:28] INFO: Computing top label features for fold.
# [11-10-2017 11:21:28] INFO: Fitting label prenylation.
# [11-10-2017 11:21:28] INFO: Preparing data.
# [11-10-2017 11:21:36] INFO: Fitting classifier.
# [11-10-2017 11:21:42] INFO: Making predictions on validation data.
# [11-10-2017 11:21:42] INFO: Making predictions on testing data.
# [11-10-2017 11:21:42] INFO: Storing validation predictions.
# [11-10-2017 11:21:42] INFO: Storing testing predictions.
# [11-10-2017 11:21:42] INFO: Computing top label features for fold.
# [11-10-2017 11:21:42] INFO: Fitting label sumoylation.
# [11-10-2017 11:21:42] INFO: Preparing data.
# [11-10-2017 11:21:49] INFO: Fitting classifier.
# [11-10-2017 11:21:59] INFO: Making predictions on validation data.
# [11-10-2017 11:21:59] INFO: Making predictions on testing data.
# [11-10-2017 11:21:59] INFO: Storing validation predictions.
# [11-10-2017 11:21:59] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:21:59] INFO: Computing top label features for fold.
# [11-10-2017 11:21:59] INFO: Fitting label dephosphorylation.
# [11-10-2017 11:21:59] INFO: Preparing data.
# [11-10-2017 11:22:06] INFO: Fitting classifier.
# [11-10-2017 11:22:17] INFO: Making predictions on validation data.
# [11-10-2017 11:22:17] INFO: Making predictions on testing data.
# [11-10-2017 11:22:17] INFO: Storing validation predictions.
# [11-10-2017 11:22:17] INFO: Storing testing predictions.
# [11-10-2017 11:22:17] INFO: Computing top label features for fold.
# [11-10-2017 11:22:17] INFO: Fitting label glycosylation.
# [11-10-2017 11:22:17] INFO: Preparing data.
# [11-10-2017 11:22:25] INFO: Fitting classifier.
# [11-10-2017 11:22:31] INFO: Making predictions on validation data.
# [11-10-2017 11:22:31] INFO: Making predictions on testing data.
# [11-10-2017 11:22:31] INFO: Storing validation predictions.
# [11-10-2017 11:22:31] INFO: Storing testing predictions.
# [11-10-2017 11:22:31] INFO: Computing top label features for fold.
# [11-10-2017 11:22:31] INFO: Fitting label inhibition.
# [11-10-2017 11:22:31] INFO: Preparing data.
# [11-10-2017 11:22:38] INFO: Fitting classifier.
# [11-10-2017 11:23:15] INFO: Making predictions on validation data.
# [11-10-2017 11:23:15] INFO: Making predictions on testing data.
# [11-10-2017 11:23:15] INFO: Storing validation predictions.
# [11-10-2017 11:23:15] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:23:15] INFO: Computing top label features for fold.
# [11-10-2017 11:23:15] INFO: Fitting label activation.
# [11-10-2017 11:23:15] INFO: Preparing data.
# [11-10-2017 11:23:22] INFO: Fitting classifier.
# [11-10-2017 11:23:59] INFO: Making predictions on validation data.
# [11-10-2017 11:23:59] INFO: Making predictions on testing data.
# [11-10-2017 11:23:59] INFO: Storing validation predictions.
# [11-10-2017 11:23:59] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:23:59] INFO: Computing top label features for fold.
# [11-10-2017 11:23:59] INFO: Fitting label methylation.
# [11-10-2017 11:23:59] INFO: Preparing data.
# [11-10-2017 11:24:07] INFO: Fitting classifier.
# [11-10-2017 11:24:14] INFO: Making predictions on validation data.
# [11-10-2017 11:24:14] INFO: Making predictions on testing data.
# [11-10-2017 11:24:14] INFO: Storing validation predictions.
# [11-10-2017 11:24:14] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:24:14] INFO: Computing top label features for fold.
# [11-10-2017 11:24:14] INFO: Fitting label dissociation.
# [11-10-2017 11:24:14] INFO: Preparing data.
# [11-10-2017 11:24:21] INFO: Fitting classifier.
# [11-10-2017 11:24:33] INFO: Making predictions on validation data.
# [11-10-2017 11:24:33] INFO: Making predictions on testing data.
# [11-10-2017 11:24:33] INFO: Storing validation predictions.
# [11-10-2017 11:24:33] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:24:33] INFO: Computing top label features for fold.
# [11-10-2017 11:24:33] INFO: Fitting label carboxylation.
# [11-10-2017 11:24:33] INFO: Preparing data.
# [11-10-2017 11:24:41] INFO: Fitting classifier.
# [11-10-2017 11:24:47] INFO: Making predictions on validation data.
# [11-10-2017 11:24:47] INFO: Making predictions on testing data.
# [11-10-2017 11:24:47] INFO: Storing validation predictions.
# [11-10-2017 11:24:47] INFO: Storing testing predictions.
# [11-10-2017 11:24:47] INFO: Computing top label features for fold.
# [11-10-2017 11:24:47] INFO: Fitting label sulfation.
# [11-10-2017 11:24:47] INFO: Preparing data.
# [11-10-2017 11:24:55] INFO: Fitting classifier.
# [11-10-2017 11:25:01] INFO: Making predictions on validation data.
# [11-10-2017 11:25:01] INFO: Making predictions on testing data.
# [11-10-2017 11:25:01] INFO: Storing validation predictions.
# [11-10-2017 11:25:01] INFO: Storing testing predictions.
# [11-10-2017 11:25:01] INFO: Computing top label features for fold.
# [11-10-2017 11:25:01] INFO: Fitting label proteolytic-cleavage.
# [11-10-2017 11:25:01] INFO: Preparing data.
# [11-10-2017 11:25:08] INFO: Fitting classifier.
# [11-10-2017 11:25:21] INFO: Making predictions on validation data.
# [11-10-2017 11:25:21] INFO: Making predictions on testing data.
# [11-10-2017 11:25:21] INFO: Storing validation predictions.
# [11-10-2017 11:25:21] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:25:21] INFO: Computing top label features for fold.
# [11-10-2017 11:25:21] INFO: Computing fold mult-label performance.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:25:23] INFO: Fitting fold iteration 4.
# [11-10-2017 11:25:23] INFO: Fitting label phosphorylation.
# [11-10-2017 11:25:23] INFO: Preparing data.
# [11-10-2017 11:25:30] INFO: Fitting classifier.
# [11-10-2017 11:26:10] INFO: Making predictions on validation data.
# [11-10-2017 11:26:10] INFO: Making predictions on testing data.
# [11-10-2017 11:26:10] INFO: Storing validation predictions.
# [11-10-2017 11:26:10] INFO: Storing testing predictions.
# [11-10-2017 11:26:10] INFO: Computing top label features for fold.
# [11-10-2017 11:26:10] INFO: Fitting label acetylation.
# [11-10-2017 11:26:10] INFO: Preparing data.
# [11-10-2017 11:26:17] INFO: Fitting classifier.
# [11-10-2017 11:26:26] INFO: Making predictions on validation data.
# [11-10-2017 11:26:26] INFO: Making predictions on testing data.
# [11-10-2017 11:26:26] INFO: Storing validation predictions.
# [11-10-2017 11:26:26] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:26:26] INFO: Computing top label features for fold.
# [11-10-2017 11:26:26] INFO: Fitting label binding/association.
# [11-10-2017 11:26:26] INFO: Preparing data.
# [11-10-2017 11:26:34] INFO: Fitting classifier.
# [11-10-2017 11:27:00] INFO: Making predictions on validation data.
# [11-10-2017 11:27:00] INFO: Making predictions on testing data.
# [11-10-2017 11:27:00] INFO: Storing validation predictions.
# [11-10-2017 11:27:00] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:27:00] INFO: Computing top label features for fold.
# [11-10-2017 11:27:00] INFO: Fitting label deacetylation.
# [11-10-2017 11:27:01] INFO: Preparing data.
# [11-10-2017 11:27:08] INFO: Fitting classifier.
# [11-10-2017 11:27:15] INFO: Making predictions on validation data.
# [11-10-2017 11:27:15] INFO: Making predictions on testing data.
# [11-10-2017 11:27:15] INFO: Storing validation predictions.
# [11-10-2017 11:27:15] INFO: Storing testing predictions.
# [11-10-2017 11:27:15] INFO: Computing top label features for fold.
# [11-10-2017 11:27:15] INFO: Fitting label ubiquitination.
# [11-10-2017 11:27:15] INFO: Preparing data.
# [11-10-2017 11:27:22] INFO: Fitting classifier.
# [11-10-2017 11:27:32] INFO: Making predictions on validation data.
# [11-10-2017 11:27:32] INFO: Making predictions on testing data.
# [11-10-2017 11:27:32] INFO: Storing validation predictions.
# [11-10-2017 11:27:32] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:27:32] INFO: Computing top label features for fold.
# [11-10-2017 11:27:32] INFO: Fitting label state-change.
# [11-10-2017 11:27:32] INFO: Preparing data.
# [11-10-2017 11:27:39] INFO: Fitting classifier.
# [11-10-2017 11:27:49] INFO: Making predictions on validation data.
# [11-10-2017 11:27:49] INFO: Making predictions on testing data.
# [11-10-2017 11:27:49] INFO: Storing validation predictions.
# [11-10-2017 11:27:49] INFO: Storing testing predictions.
# [11-10-2017 11:27:49] INFO: Computing top label features for fold.
# [11-10-2017 11:27:49] INFO: Fitting label myristoylation.
# [11-10-2017 11:27:49] INFO: Preparing data.
# [11-10-2017 11:27:57] INFO: Fitting classifier.
# [11-10-2017 11:28:03] INFO: Making predictions on validation data.
# [11-10-2017 11:28:03] INFO: Making predictions on testing data.
# [11-10-2017 11:28:03] INFO: Storing validation predictions.
# [11-10-2017 11:28:03] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 11:28:03] INFO: Computing top label features for fold.
# ...
# [11-10-2017 12:08:06] INFO: Fitting label proteolytic-cleavage.
# [11-10-2017 12:08:06] INFO: Preparing data.
# [11-10-2017 12:08:13] INFO: Fitting classifier.
# [11-10-2017 12:08:25] INFO: Making predictions on validation data.
# [11-10-2017 12:08:25] INFO: Making predictions on testing data.
# [11-10-2017 12:08:25] INFO: Storing validation predictions.
# [11-10-2017 12:08:25] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:08:26] INFO: Computing top label features for fold.
# [11-10-2017 12:08:26] INFO: Computing fold mult-label performance.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:08:27] INFO: Fitting fold iteration 5.
# [11-10-2017 12:08:27] INFO: Fitting label phosphorylation.
# [11-10-2017 12:08:27] INFO: Preparing data.
# [11-10-2017 12:08:35] INFO: Fitting classifier.
# [11-10-2017 12:09:16] INFO: Making predictions on validation data.
# [11-10-2017 12:09:16] INFO: Making predictions on testing data.
# [11-10-2017 12:09:16] INFO: Storing validation predictions.
# [11-10-2017 12:09:16] INFO: Storing testing predictions.
# [11-10-2017 12:09:16] INFO: Computing top label features for fold.
# [11-10-2017 12:09:16] INFO: Fitting label acetylation.
# [11-10-2017 12:09:16] INFO: Preparing data.
# [11-10-2017 12:09:23] INFO: Fitting classifier.
# [11-10-2017 12:09:31] INFO: Making predictions on validation data.
# [11-10-2017 12:09:31] INFO: Making predictions on testing data.
# [11-10-2017 12:09:31] INFO: Storing validation predictions.
# [11-10-2017 12:09:31] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:09:31] INFO: Computing top label features for fold.
# [11-10-2017 12:09:31] INFO: Fitting label binding/association.
# [11-10-2017 12:09:31] INFO: Preparing data.
# [11-10-2017 12:09:38] INFO: Fitting classifier.
# [11-10-2017 12:10:05] INFO: Making predictions on validation data.
# [11-10-2017 12:10:05] INFO: Making predictions on testing data.
# [11-10-2017 12:10:05] INFO: Storing validation predictions.
# [11-10-2017 12:10:05] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:10:05] INFO: Computing top label features for fold.
# [11-10-2017 12:10:05] INFO: Fitting label deacetylation.
# [11-10-2017 12:10:05] INFO: Preparing data.
# [11-10-2017 12:10:13] INFO: Fitting classifier.
# [11-10-2017 12:10:19] INFO: Making predictions on validation data.
# [11-10-2017 12:10:19] INFO: Making predictions on testing data.
# [11-10-2017 12:10:19] INFO: Storing validation predictions.
# [11-10-2017 12:10:19] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:10:19] INFO: Computing top label features for fold.
# [11-10-2017 12:10:19] INFO: Fitting label ubiquitination.
# [11-10-2017 12:10:19] INFO: Preparing data.
# [11-10-2017 12:10:27] INFO: Fitting classifier.
# [11-10-2017 12:10:36] INFO: Making predictions on validation data.
# [11-10-2017 12:10:36] INFO: Making predictions on testing data.
# [11-10-2017 12:10:36] INFO: Storing validation predictions.
# [11-10-2017 12:10:36] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:10:36] INFO: Computing top label features for fold.
# [11-10-2017 12:10:37] INFO: Fitting label state-change.
# [11-10-2017 12:10:37] INFO: Preparing data.
# [11-10-2017 12:10:44] INFO: Fitting classifier.
# [11-10-2017 12:10:54] INFO: Making predictions on validation data.
# [11-10-2017 12:10:54] INFO: Making predictions on testing data.
# [11-10-2017 12:10:54] INFO: Storing validation predictions.
# [11-10-2017 12:10:54] INFO: Storing testing predictions.
# [11-10-2017 12:10:54] INFO: Computing top label features for fold.
# [11-10-2017 12:10:54] INFO: Fitting label myristoylation.
# [11-10-2017 12:10:54] INFO: Preparing data.
# [11-10-2017 12:11:02] INFO: Fitting classifier.
# [11-10-2017 12:11:07] INFO: Making predictions on validation data.
# [11-10-2017 12:11:07] INFO: Making predictions on testing data.
# [11-10-2017 12:11:07] INFO: Storing validation predictions.
# [11-10-2017 12:11:07] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:11:07] INFO: Computing top label features for fold.
# [11-10-2017 12:11:07] INFO: Fitting label prenylation.
# [11-10-2017 12:11:07] INFO: Preparing data.
# [11-10-2017 12:11:14] INFO: Fitting classifier.
# [11-10-2017 12:11:20] INFO: Making predictions on validation data.
# [11-10-2017 12:11:20] INFO: Making predictions on testing data.
# [11-10-2017 12:11:20] INFO: Storing validation predictions.
# [11-10-2017 12:11:20] INFO: Storing testing predictions.
# [11-10-2017 12:11:20] INFO: Computing top label features for fold.
# [11-10-2017 12:11:20] INFO: Fitting label sumoylation.
# [11-10-2017 12:11:20] INFO: Preparing data.
# [11-10-2017 12:11:28] INFO: Fitting classifier.
# [11-10-2017 12:11:37] INFO: Making predictions on validation data.
# [11-10-2017 12:11:37] INFO: Making predictions on testing data.
# [11-10-2017 12:11:37] INFO: Storing validation predictions.
# [11-10-2017 12:11:37] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:11:37] INFO: Computing top label features for fold.
# [11-10-2017 12:11:37] INFO: Fitting label dephosphorylation.
# [11-10-2017 12:11:37] INFO: Preparing data.
# [11-10-2017 12:11:44] INFO: Fitting classifier.
# [11-10-2017 12:11:55] INFO: Making predictions on validation data.
# [11-10-2017 12:11:55] INFO: Making predictions on testing data.
# [11-10-2017 12:11:55] INFO: Storing validation predictions.
# [11-10-2017 12:11:55] INFO: Storing testing predictions.
# [11-10-2017 12:11:55] INFO: Computing top label features for fold.
# [11-10-2017 12:11:55] INFO: Fitting label glycosylation.
# [11-10-2017 12:11:55] INFO: Preparing data.
# [11-10-2017 12:12:02] INFO: Fitting classifier.
# [11-10-2017 12:12:08] INFO: Making predictions on validation data.
# [11-10-2017 12:12:08] INFO: Making predictions on testing data.
# [11-10-2017 12:12:08] INFO: Storing validation predictions.
# [11-10-2017 12:12:08] INFO: Storing testing predictions.
# [11-10-2017 12:12:08] INFO: Computing top label features for fold.
# [11-10-2017 12:12:08] INFO: Fitting label inhibition.
# [11-10-2017 12:12:08] INFO: Preparing data.
# [11-10-2017 12:12:16] INFO: Fitting classifier.
# [11-10-2017 12:12:46] INFO: Making predictions on validation data.
# [11-10-2017 12:12:46] INFO: Making predictions on testing data.
# [11-10-2017 12:12:46] INFO: Storing validation predictions.
# [11-10-2017 12:12:46] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:12:46] INFO: Computing top label features for fold.
# [11-10-2017 12:12:46] INFO: Fitting label activation.
# [11-10-2017 12:12:46] INFO: Preparing data.
# [11-10-2017 12:12:54] INFO: Fitting classifier.
# [11-10-2017 12:13:41] INFO: Making predictions on validation data.
# [11-10-2017 12:13:41] INFO: Making predictions on testing data.
# [11-10-2017 12:13:41] INFO: Storing validation predictions.
# [11-10-2017 12:13:41] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:13:41] INFO: Computing top label features for fold.
# [11-10-2017 12:13:41] INFO: Fitting label methylation.
# [11-10-2017 12:13:41] INFO: Preparing data.
# [11-10-2017 12:13:48] INFO: Fitting classifier.
# [11-10-2017 12:13:55] INFO: Making predictions on validation data.
# [11-10-2017 12:13:55] INFO: Making predictions on testing data.
# [11-10-2017 12:13:55] INFO: Storing validation predictions.
# [11-10-2017 12:13:55] INFO: Storing testing predictions.
# [11-10-2017 12:13:55] INFO: Computing top label features for fold.
# [11-10-2017 12:13:55] INFO: Fitting label dissociation.
# [11-10-2017 12:13:55] INFO: Preparing data.
# [11-10-2017 12:14:03] INFO: Fitting classifier.
# [11-10-2017 12:14:16] INFO: Making predictions on validation data.
# [11-10-2017 12:14:17] INFO: Making predictions on testing data.
# [11-10-2017 12:14:17] INFO: Storing validation predictions.
# [11-10-2017 12:14:17] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:14:17] INFO: Computing top label features for fold.
# [11-10-2017 12:14:17] INFO: Fitting label carboxylation.
# [11-10-2017 12:14:17] INFO: Preparing data.
# [11-10-2017 12:14:24] INFO: Fitting classifier.
# [11-10-2017 12:14:29] INFO: Making predictions on validation data.
# [11-10-2017 12:14:29] INFO: Making predictions on testing data.
# [11-10-2017 12:14:29] INFO: Storing validation predictions.
# [11-10-2017 12:14:29] INFO: Storing testing predictions.
# [11-10-2017 12:14:29] INFO: Computing top label features for fold.
# [11-10-2017 12:14:29] INFO: Fitting label sulfation.
# [11-10-2017 12:14:29] INFO: Preparing data.
# [11-10-2017 12:14:37] INFO: Fitting classifier.
# [11-10-2017 12:14:42] INFO: Making predictions on validation data.
# [11-10-2017 12:14:42] INFO: Making predictions on testing data.
# [11-10-2017 12:14:42] INFO: Storing validation predictions.
# [11-10-2017 12:14:42] INFO: Storing testing predictions.
# [11-10-2017 12:14:42] INFO: Computing top label features for fold.
# [11-10-2017 12:14:43] INFO: Fitting label proteolytic-cleavage.
# [11-10-2017 12:14:43] INFO: Preparing data.
# [11-10-2017 12:14:50] INFO: Fitting classifier.
# [11-10-2017 12:15:02] INFO: Making predictions on validation data.
# [11-10-2017 12:15:02] INFO: Making predictions on testing data.
# [11-10-2017 12:15:02] INFO: Storing validation predictions.
# [11-10-2017 12:15:02] INFO: Storing testing predictions.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples.
#   'recall', 'true', average, warn_for)
# [11-10-2017 12:15:02] INFO: Computing top label features for fold.
# [11-10-2017 12:15:02] INFO: Computing fold mult-label performance.
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\scikit_learn-0.18.2-py3.5-win-amd64.egg\sklearn\metrics\classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# Write out all the statistics to a multi-indexed dataframe
# -------------------------------------------------------------------- #
logging.info("Writing statistics to file.")

# Binary Statistics
# -------------------------------------------------------------------- #
dim_a_size = len(mlb.classes) * 2 * len(binary_scoring_funcs)
dim_b_size = n_iter * n_splits

func_names = [n for n, _ in binary_scoring_funcs]
iterables = [mlb.classes, ["validation", "holdout"], func_names]
names = ['Labels', 'Condition', 'Metric']
tuples = list(product(*iterables))
index = pd.MultiIndex.from_tuples(tuples, names=names)

names = ['Bootstrap Iteration', 'Fold Iteration']
arrays = [
    ['B{}'.format(i+1) for i in range(n_iter)],
    ['F{}'.format(i+1) for i in range(n_splits)]
]
tuples = list(product(*arrays))
columns = pd.MultiIndex.from_tuples(tuples, names=names)

binary_df = pd.DataFrame(
    binary_statistics.reshape((dim_a_size, dim_b_size)),
    index=index, columns=columns
).sort_index()
binary_df.to_csv('{}/{}'.format(direc, 'binary_stats.csv'), sep=',')

# Multi-label Statistics
# -------------------------------------------------------------------- #
dim_a_size = 2 * len(multilabel_scoring_funcs)
dim_b_size = n_iter * n_splits

func_names = [n for n, _ in multilabel_scoring_funcs]
iterables = [["validation", "holdout"], func_names]
names = ['Condition', 'Metric']
tuples = list(product(*iterables))
index = pd.MultiIndex.from_tuples(tuples, names=names)

names = ['Bootstrap Iteration', 'Fold Iteration']
arrays = [
    ['B{}'.format(i+1) for i in range(n_iter)],
    ['F{}'.format(i+1) for i in range(n_splits)]
]
tuples = list(product(*arrays))
columns = pd.MultiIndex.from_tuples(tuples, names=names)

multilabel_df = pd.DataFrame(
    multilabel_statistics.reshape((dim_a_size, dim_b_size)),
    index=index, columns=columns
).sort_index()
multilabel_df.to_csv(
    '{}/{}'.format(direc, 'multilabel_stats.csv'), sep=','
)

# Top N Features, train/y-array index order
# -------------------------------------------------------------------- #
logging.info("Writing label training order.")
with open("{}/{}".format(direc, "label_order.csv"), 'wt') as fp:
    fp.write(",".join(mlb.classes))

logging.info("Writing top features to file.")
with open('{}/{}'.format(direc, 'top_features.json'), 'wt') as fp:
    json.dump(top_features, fp, indent=4, sort_keys=True)
# Out:
# [11-10-2017 12:24:18] INFO: Writing statistics to file.
# [11-10-2017 12:24:18] INFO: Writing label training order.
# [11-10-2017 12:24:18] INFO: Writing top features to file.

# %%
# Compute label similarity heatmaps and label correlation heatmap
# -------------------------------------------------------------------- #
label_features = {l: set() for l in mlb.classes}
for idx, label in enumerate(mlb.classes):
    selector = y_train[:, idx] == 1
    positive_cases = X_train[selector]
    for feature_string in positive_cases:
        unique = set(feature_string.split(','))
        label_features[label] |= unique
        
j_v_similarity_matrix = np.zeros((len(mlb.classes), len(mlb.classes)))
d_v_similarity_matrix = np.zeros((len(mlb.classes), len(mlb.classes)))
for i, class_1 in enumerate(sorted(mlb.classes)):
    for j, class_2 in enumerate(sorted(mlb.classes)):
        set_1 = label_features[class_1]
        set_2 = label_features[class_2]
        jaccard = len(set_1 & set_2) / len(set_1 | set_2)
        dice = 2 * len(set_1 & set_2) / (len(set_1) + len(set_2))
        j_v_similarity_matrix[i, j] = jaccard
        d_v_similarity_matrix[i, j] = dice
        

# Create label correlation matrix and then create a new one
# Where the columns and rows are in alphabetical order.
label_correlation, _ = sp.stats.spearmanr(y_train)
s_label_correlation = np.zeros_like(label_correlation)
for i, class_1 in enumerate(sorted(mlb.classes)):
    for j, class_2 in enumerate(sorted(mlb.classes)):
        index_1 = mlb.classes.index(class_1)
        index_2 = mlb.classes.index(class_2)
        s_label_correlation[i, j] = label_correlation[index_1, index_2]


header = "Columns: {}\nRows: {}".format(
    ','.join(sorted(mlb.classes)), ','.join(sorted(mlb.classes))
)
np.savetxt(
    X=j_v_similarity_matrix,
    fname='{}/{}'.format(direc, 'j_v_similarity_matrix.csv'),
    header=header, delimiter=','
)
np.savetxt(
    X=d_v_similarity_matrix,
    fname='{}/{}'.format(direc, 'd_v_similarity_matrix.csv'),
    header=header, delimiter=','
)
np.savetxt(
    X=s_label_correlation, fname='{}/{}'.format(direc, 'label_spearmanr.csv'),
    header=header, delimiter=','
)

# %%
# Compute label similarity heatmaps for the holdout set
# -------------------------------------------------------------------- #
holdout_labels = ('dephosphorylation', 'phosphorylation')
holdout_label_features = {l: set() for l in holdout_labels}
for idx, label in enumerate(mlb.classes):
    if label in holdout_labels:
        selector = y_test[:, idx] == 1
        positive_cases = X_test[selector]
        for feature_string in positive_cases:
            unique = set(feature_string.split(','))
            holdout_label_features[label] |= unique
        
j_t_similarity_matrix = np.zeros((2, len(mlb.classes)))
d_t_similarity_matrix = np.zeros((2, len(mlb.classes)))
for i, class_1 in enumerate(sorted(holdout_labels)):
    for j, class_2 in enumerate(sorted(mlb.classes)):
        set_1 = holdout_label_features[class_1]
        set_2 = label_features[class_2]
        jaccard = len(set_1 & set_2) / len(set_1 | set_2)
        dice = 2 * len(set_1 & set_2) / (len(set_1) + len(set_2))
        print(class_1, class_2, jaccard)
        j_t_similarity_matrix[i, j] = jaccard
        d_t_similarity_matrix[i, j] = dice
        
header = "Columns: {}\nRows: {}".format(
    ','.join(sorted(mlb.classes)), ','.join(sorted(holdout_labels))
)
np.savetxt(
    X=j_t_similarity_matrix, 
    fname='{}/{}'.format(direc, 'j_t_similarity_matrix.csv'), 
    header=header, delimiter=','
)
np.savetxt(
    X=d_t_similarity_matrix, 
    fname='{}/{}'.format(direc, 'd_t_similarity_matrix.csv'), 
    header=header, delimiter=','
)
# Out:
# dephosphorylation acetylation 0.14422288992078666
# dephosphorylation activation 0.18240910014218972
# dephosphorylation binding/association 0.22319705211440605
# dephosphorylation carboxylation 0.01785123966942149
# dephosphorylation deacetylation 0.07436460621273926
# dephosphorylation dephosphorylation 0.3471575966012543
# dephosphorylation dissociation 0.23177392543338873
# dephosphorylation glycosylation 0.1863555818074424
# dephosphorylation inhibition 0.2335575485799701
# dephosphorylation methylation 0.12930788949017374
# dephosphorylation myristoylation 0.11840796019900497
# dephosphorylation phosphorylation 0.2721546961325967
# dephosphorylation prenylation 0.0901301174230403
# dephosphorylation proteolytic-cleavage 0.26478790547482756
# dephosphorylation state-change 0.12416979497545481
# dephosphorylation sulfation 0.03739837398373984
# dephosphorylation sumoylation 0.15611233480176212
# dephosphorylation ubiquitination 0.29368372521899494
# phosphorylation acetylation 0.10865648999715559
# phosphorylation activation 0.4871932332618537
# phosphorylation binding/association 0.4930381509328878
# phosphorylation carboxylation 0.008673274876096072
# phosphorylation deacetylation 0.040266539742979536
# phosphorylation dephosphorylation 0.29959625619379704
# phosphorylation dissociation 0.18419333768778576
# phosphorylation glycosylation 0.0922449753507774
# phosphorylation inhibition 0.49300648882480175
# phosphorylation methylation 0.07882607468723545
# phosphorylation myristoylation 0.039273769708552314
# phosphorylation phosphorylation 0.5290664951354829
# phosphorylation prenylation 0.03824981017463933
# phosphorylation proteolytic-cleavage 0.3324241672865526
# phosphorylation state-change 0.0764072534945221
# phosphorylation sulfation 0.02100439182738209
# phosphorylation sumoylation 0.10145882352941177
# phosphorylation ubiquitination 0.20851377499308946
