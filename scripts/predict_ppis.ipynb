# %%
# %reload_ext autoreload

"""
This script runs classifier training over the entire training data and then
output predictions over the interactome.

Usage:
  predict_ppis.py [--interpro] [--pfam] [--mf] [--cc] [--bp]
                  [--use_cache] [--retrain] [--induce] [--verbose]
                  [--model=M] [--n_jobs=J] [--n_splits=S] [--n_iterations=I]
                  [--input=FILE] [--output=FILE] [--directory=DIR]
  predict_ppis.py -h | --help

Options:
  -h --help     Show this screen.
  --interpro    Use interpro domains in features.
  --pfam        Use Pfam domains in features.
  --mf          Use Molecular Function Gene Ontology in features.
  --cc          Use Cellular Compartment Gene Ontology in features.
  --bp          Use Biological Process Gene Ontology in features.
  --induce      Use ULCA inducer over Gene Ontology.
  --verbose     Print intermediate output for debugging.
  --binary      Use binary feature encoding instead of ternary.
  --use_cache   Use cached features if available.
  --retrain     Re-train classifier instead of loading previous version. If
                using a previous version, you must use the same selection of
                features along with the same induce setting.
  --model=M         A binary classifier from Scikit-Learn implementing fit,
                    predict and predict_proba [default: LogisticRegression].
                    Ignored if using 'retrain'.
  --n_jobs=J        Number of processes to run in parallel [default: 1]
  --n_splits=S      Number of cross-validation splits used during randomized
                    grid search [default: 5]
  --n_iterations=I  Number of randomized grid search iterations [default: 60]
  --input=FILE      Uniprot edge-list, with a path directory that absolute or
                    relative to this script. Entries must be tab separated with
                    header columns 'source' and 'target'. [default: 'default']
  --output=FILE     Output file name [default: predictions.tsv]
  --directory=DIR   Absolute or relative output directory [default: ./results/]
"""

import os
import json
import logging
import numpy as np
from datetime import datetime

from pyppi.base import parse_args, su_make_dir
from pyppi.base import P1, P2, G1, G2
from pyppi.data import load_network_from_path, load_ptm_labels
from pyppi.data import full_training_network_path, generic_io
from pyppi.data import interactome_network_path, classifier_path

from pyppi.models import make_classifier, get_parameter_distribution_for_model

from pyppi.data_mining.features import AnnotationExtractor
from pyppi.data_mining.uniprot import UniProt, get_active_instance
from pyppi.data_mining.tools import xy_from_interaction_frame
from pyppi.data_mining.generic import edgelist_func, generic_to_dataframe
from pyppi.data_mining.tools import map_network_accessions

from sklearn.externals import joblib
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import RandomizedSearchCV
from sklearn.multiclass import OneVsRestClassifier

logging.captureWarnings(False)
logging.basicConfig(
    format='[%(asctime)s] %(levelname)s: %(message)s',
    datefmt='%m-%d-%Y %I:%M:%S',
    level=logging.DEBUG,
)
logger = logging.getLogger(__name__)

args = dict(
    n_jobs=3,
    n_splits=2,
    rcv_iter=10,
    induce=True,
    verbose=True,
    selection = [
        UniProt.data_types().GO_MF.value,
        UniProt.data_types().GO_BP.value,
        UniProt.data_types().GO_CC.value,
        UniProt.data_types().INTERPRO.value,
        UniProt.data_types().PFAM.value
    ],
    model='LogisticRegression',
    use_cache=True,
    output='predictions.tsv',
    input='test_network.tsv',
    direc='./results/',
    retrain=True,
    use_binary=False
)
n_jobs = args['n_jobs']
n_splits = args['n_splits']
rcv_iter = args['rcv_iter']
induce = args['induce']
verbose = args['verbose']
selection = args['selection']
model = args['model']
use_feature_cache = args['use_cache']
out_file = args['output']
input_file = args['input']
direc = args['direc']
retrain = args['retrain']
use_binary = args['use_binary']

# %%
# Set up the folder for each experiment run named after the current time
# -------------------------------------------------------------------- #
folder = datetime.now().strftime("pred_%y-%m-%d_%H-%M-%S")
direc = "{}/{}/".format(direc, folder)
su_make_dir(direc)
json.dump(args, fp=open("{}/settings.json".format(direc), 'w'), indent=4,
          sort_keys=True)
out_file = open("{}/{}".format(direc, out_file), "w")

# %%
# Load features from feature cache, or create an empty annotation extrator
# ------------------------------------------------------------------------ #
logger.info("Loading feature data...")
uniprot = get_active_instance(verbose=verbose)
data_types = UniProt.data_types()
labels = load_ptm_labels()
annotation_ex = AnnotationExtractor(
    induce=induce,
    selection=selection,
    n_jobs=n_jobs,
    verbose=verbose,
    cache=use_feature_cache
)
# Out:
# [11-17-2017 05:58:39] INFO: Loading feature data...
# First time loading on UniProt instance. Make take a few moments
# Warning: Loading dat files, may take a few minutes.

# %%
# Get the input edge-list ready
# -------------------------------------------------------------------- #
if input_file == 'default':
    logger.info("Loading interactome data...")
    testing = load_network_from_path(interactome_network_path)
else:
    logger.info("Loading custom ppi data...")
    testing = generic_to_dataframe(
        f_input=generic_io(input_file),
        parsing_func=edgelist_func,
        drop_nan=True,
        allow_self_edges=True,
        allow_duplicates=True
    )
    sources = set(p for p in testing.source.values)
    targets = set(p for p in testing.target.values)
    accessions = list(sources | targets)
    accession_mapping = uniprot.batch_map(accessions)
    testing = map_network_accessions(
        interactions=testing, accession_map=accession_mapping,
        drop_nan=True, allow_self_edges=True,
        allow_duplicates=False, min_counts=None, merge=False
    )

# %%
# Get the features into X, and multilabel y indicator format
# -------------------------------------------------------------------- #
logger.info("Preparing training and testing data...")
training = load_network_from_path(full_training_network_path)
X_train_ppis, y_train = xy_from_interaction_frame(training)
X_test_ppis, _ = xy_from_interaction_frame(testing)

if not use_feature_cache:
    logger.info("Computing feature cache.")
    annotation_ex.fit(X_train_ppis + X_test_ppis)
    X_train = annotation_ex.transform(X_train_ppis)
    X_test = annotation_ex.transform(X_test_ppis)
else:
    try:
        X_train = annotation_ex.transform(X_train_ppis)
        X_test = annotation_ex.transform(X_test_ppis)
    except ValueError:
        logger.info("Found new PPIs. Re-computing feature cache.")
        annotation_ex.fit(X_train_ppis + X_test_ppis)
        X_train = annotation_ex.transform(X_train_ppis)
        X_test = annotation_ex.transform(X_test_ppis)

# Get all annotations used during training
# -------------------------------------------------------------------- #
training_go = set([
    g.strip() for gs in X_train
    for g in x.split(',')
    if 'go' in g.strip().lower()
])
training_pfam = set([
    g.strip() for gs in X_train
    for g in x.split(',')
    if 'pf' in g.strip().lower()
])
training_ipr = set([
    g.strip() for gs in X_train
    for g in x.split(',')
    if 'ipr' in g.strip().lower()
])

mlb = MultiLabelBinarizer(classes=sorted(labels))
mlb.fit(y_train)
y_train = mlb.transform(y_train)

vectorizer = CountVectorizer(binary=True if use_binary else False)
X_train = vectorizer.fit_transform(X_train)
# Out:
# Acquiring features for PPIs...
# Acquiring data for accession 1/4029..
# Acquiring data for accession 2/4029..
# Acquiring data for accession 3/4029..
# Acquiring data for accession 4/4029..
# Acquiring data for accession 5/4029..
# Acquiring data for accession 6/4029..
# Acquiring data for accession 7/4029..
# Acquiring data for accession 8/4029..
# Acquiring data for accession 9/4029..
# Acquiring data for accession 10/4029..
# Acquiring data for accession 11/4029..
# Acquiring data for accession 12/4029..
# Acquiring data for accession 13/4029..
# Acquiring data for accession 14/4029..
# Acquiring data for accession 15/4029..
# Acquiring data for accession 16/4029..
# Acquiring data for accession 17/4029..
# Acquiring data for accession 18/4029..
# Acquiring data for accession 19/4029..
# Acquiring data for accession 20/4029..
# Acquiring data for accession 21/4029..
# Acquiring data for accession 22/4029..
# Acquiring data for accession 23/4029..
# Acquiring data for accession 24/4029..
# Acquiring data for accession 25/4029..
# Acquiring data for accession 26/4029..
# Acquiring data for accession 27/4029..
# Acquiring data for accession 28/4029..
# Acquiring data for accession 29/4029..
# Acquiring data for accession 30/4029..
# Acquiring data for accession 31/4029..
# Acquiring data for accession 32/4029..
# Acquiring data for accession 33/4029..
# Acquiring data for accession 34/4029..
# Acquiring data for accession 35/4029..
# Acquiring data for accession 36/4029..
# Acquiring data for accession 37/4029..
# Acquiring data for accession 38/4029..
# Acquiring data for accession 39/4029..
# Acquiring data for accession 40/4029..
# Acquiring data for accession 41/4029..
# Acquiring data for accession 42/4029..
# Acquiring data for accession 43/4029..
# Acquiring data for accession 44/4029..
# Acquiring data for accession 45/4029..
# Acquiring data for accession 46/4029..
# Acquiring data for accession 47/4029..
# Acquiring data for accession 48/4029..
# Acquiring data for accession 49/4029..
# Acquiring data for accession 50/4029..
# Acquiring data for accession 51/4029..
# Acquiring data for accession 52/4029..
# Acquiring data for accession 53/4029..
# Acquiring data for accession 54/4029..
# Acquiring data for accession 55/4029..
# Acquiring data for accession 56/4029..
# Acquiring data for accession 57/4029..
# Acquiring data for accession 58/4029..
# Acquiring data for accession 59/4029..
# Acquiring data for accession 60/4029..
# Acquiring data for accession 61/4029..
# Acquiring data for accession 62/4029..
# Acquiring data for accession 63/4029..
# Acquiring data for accession 64/4029..
# Acquiring data for accession 65/4029..
# Acquiring data for accession 66/4029..
# Acquiring data for accession 67/4029..
# Acquiring data for accession 68/4029..
# Acquiring data for accession 69/4029..
# Acquiring data for accession 70/4029..
# Acquiring data for accession 71/4029..
# Acquiring data for accession 72/4029..
# Acquiring data for accession 73/4029..
# Acquiring data for accession 74/4029..
# Acquiring data for accession 75/4029..
# Acquiring data for accession 76/4029..
# Acquiring data for accession 77/4029..
# Acquiring data for accession 78/4029..
# Acquiring data for accession 79/4029..
# Acquiring data for accession 80/4029..
# Acquiring data for accession 81/4029..
# Acquiring data for accession 82/4029..
# Acquiring data for accession 83/4029..
# Acquiring data for accession 84/4029..
# Acquiring data for accession 85/4029..
# Acquiring data for accession 86/4029..
# Acquiring data for accession 87/4029..
# Acquiring data for accession 88/4029..
# Acquiring data for accession 89/4029..
# Acquiring data for accession 90/4029..
# Acquiring data for accession 91/4029..
# Acquiring data for accession 92/4029..
# Acquiring data for accession 93/4029..
# Acquiring data for accession 94/4029..
# Acquiring data for accession 95/4029..
# Acquiring data for accession 96/4029..
# Acquiring data for accession 97/4029..
# Acquiring data for accession 98/4029..
# Acquiring data for accession 99/4029..
# Acquiring data for accession 100/4029..
# Acquiring data for accession 101/4029..
# Acquiring data for accession 102/4029..
# Acquiring data for accession 103/4029..
# Acquiring data for accession 104/4029..
# Acquiring data for accession 105/4029..
# Acquiring data for accession 106/4029..
# Acquiring data for accession 107/4029..
# Acquiring data for accession 108/4029..
# Acquiring data for accession 109/4029..
# Acquiring data for accession 110/4029..
# Acquiring data for accession 111/4029..
# Acquiring data for accession 112/4029..
# Acquiring data for accession 113/4029..
# Acquiring data for accession 114/4029..
# Acquiring data for accession 115/4029..
# Acquiring data for accession 116/4029..
# Acquiring data for accession 117/4029..
# Acquiring data for accession 118/4029..
# Acquiring data for accession 119/4029..
# Acquiring data for accession 120/4029..
# Acquiring data for accession 121/4029..
# Acquiring data for accession 122/4029..
# Acquiring data for accession 123/4029..
# Acquiring data for accession 124/4029..
# Acquiring data for accession 125/4029..
# Acquiring data for accession 126/4029..
# Acquiring data for accession 127/4029..
# Acquiring data for accession 128/4029..
# Acquiring data for accession 129/4029..
# Acquiring data for accession 130/4029..
# Acquiring data for accession 131/4029..
# Acquiring data for accession 132/4029..
# Acquiring data for accession 133/4029..
# Acquiring data for accession 134/4029..
# Acquiring data for accession 135/4029..
# Acquiring data for accession 136/4029..
# Acquiring data for accession 137/4029..
# Acquiring data for accession 138/4029..
# Acquiring data for accession 139/4029..
# Acquiring data for accession 140/4029..
# Acquiring data for accession 141/4029..
# Acquiring data for accession 142/4029..
# Acquiring data for accession 143/4029..
# Acquiring data for accession 144/4029..
# Acquiring data for accession 145/4029..
# Acquiring data for accession 146/4029..
# Acquiring data for accession 147/4029..
# Acquiring data for accession 148/4029..
# Acquiring data for accession 149/4029..
# Acquiring data for accession 150/4029..
# Acquiring data for accession 151/4029..
# Acquiring data for accession 152/4029..
# Acquiring data for accession 153/4029..
# Acquiring data for accession 154/4029..
# Acquiring data for accession 155/4029..
# Acquiring data for accession 156/4029..
# Acquiring data for accession 157/4029..
# Acquiring data for accession 158/4029..
# Acquiring data for accession 159/4029..
# Acquiring data for accession 160/4029..
# Acquiring data for accession 161/4029..
# Acquiring data for accession 162/4029..
# Acquiring data for accession 163/4029..
# Acquiring data for accession 164/4029..
# Acquiring data for accession 165/4029..
# Acquiring data for accession 166/4029..
# Acquiring data for accession 167/4029..
# Acquiring data for accession 168/4029..
# Acquiring data for accession 169/4029..
# Acquiring data for accession 170/4029..
# Acquiring data for accession 171/4029..
# Acquiring data for accession 172/4029..
# Acquiring data for accession 173/4029..
# Acquiring data for accession 174/4029..
# Acquiring data for accession 175/4029..
# Acquiring data for accession 176/4029..
# Acquiring data for accession 177/4029..
# Acquiring data for accession 178/4029..
# Acquiring data for accession 179/4029..
# Acquiring data for accession 180/4029..
# Acquiring data for accession 181/4029..
# Acquiring data for accession 182/4029..
# Acquiring data for accession 183/4029..
# Acquiring data for accession 184/4029..
# Acquiring data for accession 185/4029..
# Acquiring data for accession 186/4029..
# Acquiring data for accession 187/4029..
# Acquiring data for accession 188/4029..
# Acquiring data for accession 189/4029..
# Acquiring data for accession 190/4029..
# Acquiring data for accession 191/4029..
# Acquiring data for accession 192/4029..
# Acquiring data for accession 193/4029..
# Acquiring data for accession 194/4029..
# Acquiring data for accession 195/4029..
# Acquiring data for accession 196/4029..
# Acquiring data for accession 197/4029..
# Acquiring data for accession 198/4029..
# Acquiring data for accession 199/4029..
# Acquiring data for accession 200/4029..
# Acquiring data for accession 201/4029..
# Acquiring data for accession 202/4029..
# Acquiring data for accession 203/4029..
# Acquiring data for accession 204/4029..
# Acquiring data for accession 205/4029..
# Acquiring data for accession 206/4029..
# Acquiring data for accession 207/4029..
# Acquiring data for accession 208/4029..
# Acquiring data for accession 209/4029..
# Acquiring data for accession 210/4029..
# Acquiring data for accession 211/4029..
# Acquiring data for accession 212/4029..
# Acquiring data for accession 213/4029..
# Acquiring data for accession 214/4029..
# Acquiring data for accession 215/4029..
# Acquiring data for accession 216/4029..
# Acquiring data for accession 217/4029..
# Acquiring data for accession 218/4029..
# Acquiring data for accession 219/4029..
# Acquiring data for accession 220/4029..
# Acquiring data for accession 221/4029..
# Acquiring data for accession 222/4029..
# Acquiring data for accession 223/4029..
# Acquiring data for accession 224/4029..
# Acquiring data for accession 225/4029..
# Acquiring data for accession 226/4029..
# Acquiring data for accession 227/4029..
# Acquiring data for accession 228/4029..
# Acquiring data for accession 229/4029..
# Acquiring data for accession 230/4029..
# Acquiring data for accession 231/4029..
# Acquiring data for accession 232/4029..
# Acquiring data for accession 233/4029..
# Acquiring data for accession 234/4029..
# Acquiring data for accession 235/4029..
# Acquiring data for accession 236/4029..
# Acquiring data for accession 237/4029..
# Acquiring data for accession 238/4029..
# Acquiring data for accession 239/4029..
# Acquiring data for accession 240/4029..
# Acquiring data for accession 241/4029..
# Acquiring data for accession 242/4029..
# Acquiring data for accession 243/4029..
# Acquiring data for accession 244/4029..
# Acquiring data for accession 245/4029..
# Acquiring data for accession 246/4029..
# Acquiring data for accession 247/4029..
# Acquiring data for accession 248/4029..
# Acquiring data for accession 249/4029..
# Acquiring data for accession 250/4029..
# Acquiring data for accession 251/4029..
# Acquiring data for accession 252/4029..
# Acquiring data for accession 253/4029..
# Acquiring data for accession 254/4029..
# Acquiring data for accession 255/4029..
# Acquiring data for accession 256/4029..
# Acquiring data for accession 257/4029..
# Acquiring data for accession 258/4029..
# Acquiring data for accession 259/4029..
# Acquiring data for accession 260/4029..
# Acquiring data for accession 261/4029..
# Acquiring data for accession 262/4029..
# Acquiring data for accession 263/4029..
# Acquiring data for accession 264/4029..
# Acquiring data for accession 265/4029..
# Acquiring data for accession 266/4029..
# Acquiring data for accession 267/4029..
# Acquiring data for accession 268/4029..
# Acquiring data for accession 269/4029..
# Acquiring data for accession 270/4029..
# Acquiring data for accession 271/4029..
# Acquiring data for accession 272/4029..
# Acquiring data for accession 273/4029..
# Acquiring data for accession 274/4029..
# Acquiring data for accession 275/4029..
# Acquiring data for accession 276/4029..
# Acquiring data for accession 277/4029..
# Acquiring data for accession 278/4029..
# Acquiring data for accession 279/4029..
# Acquiring data for accession 280/4029..
# Acquiring data for accession 281/4029..
# Acquiring data for accession 282/4029..
# Acquiring data for accession 283/4029..
# Acquiring data for accession 284/4029..
# Acquiring data for accession 285/4029..
# Acquiring data for accession 286/4029..
# Acquiring data for accession 287/4029..
# Acquiring data for accession 288/4029..
# Acquiring data for accession 289/4029..
# Acquiring data for accession 290/4029..
# Acquiring data for accession 291/4029..
# Acquiring data for accession 292/4029..
# Acquiring data for accession 293/4029..
# Acquiring data for accession 294/4029..
# Acquiring data for accession 295/4029..
# Acquiring data for accession 296/4029..
# Acquiring data for accession 297/4029..
# Acquiring data for accession 298/4029..
# Acquiring data for accession 299/4029..
# Acquiring data for accession 300/4029..
# Acquiring data for accession 301/4029..
# Acquiring data for accession 302/4029..
# Acquiring data for accession 303/4029..
# Acquiring data for accession 304/4029..
# Acquiring data for accession 305/4029..
# Acquiring data for accession 306/4029..
# Acquiring data for accession 307/4029..
# Acquiring data for accession 308/4029..
# Acquiring data for accession 309/4029..
# Acquiring data for accession 310/4029..
# Acquiring data for accession 311/4029..
# Acquiring data for accession 312/4029..
# Acquiring data for accession 313/4029..
# Acquiring data for accession 314/4029..
# Acquiring data for accession 315/4029..
# Acquiring data for accession 316/4029..
# Acquiring data for accession 317/4029..
# Acquiring data for accession 318/4029..
# Acquiring data for accession 319/4029..
# Acquiring data for accession 320/4029..
# Acquiring data for accession 321/4029..
# Acquiring data for accession 322/4029..
# Acquiring data for accession 323/4029..
# Acquiring data for accession 324/4029..
# Acquiring data for accession 325/4029..
# Acquiring data for accession 326/4029..
# Acquiring data for accession 327/4029..
# Acquiring data for accession 328/4029..
# Acquiring data for accession 329/4029..
# Acquiring data for accession 330/4029..
# Acquiring data for accession 331/4029..
# Acquiring data for accession 332/4029..
# Acquiring data for accession 333/4029..
# Acquiring data for accession 334/4029..
# Acquiring data for accession 335/4029..
# Acquiring data for accession 336/4029..
# Acquiring data for accession 337/4029..
# Acquiring data for accession 338/4029..
# Acquiring data for accession 339/4029..
# Acquiring data for accession 340/4029..
# Acquiring data for accession 341/4029..
# Acquiring data for accession 342/4029..
# Acquiring data for accession 343/4029..
# Acquiring data for accession 344/4029..
# Acquiring data for accession 345/4029..
# Acquiring data for accession 346/4029..
# Acquiring data for accession 347/4029..
# Acquiring data for accession 348/4029..
# Acquiring data for accession 349/4029..
# Acquiring data for accession 350/4029..
# Acquiring data for accession 351/4029..
# Acquiring data for accession 352/4029..
# Acquiring data for accession 353/4029..
# Acquiring data for accession 354/4029..
# Acquiring data for accession 355/4029..
# Acquiring data for accession 356/4029..
# Acquiring data for accession 357/4029..
# Acquiring data for accession 358/4029..
# Acquiring data for accession 359/4029..
# Acquiring data for accession 360/4029..
# Acquiring data for accession 361/4029..
# Acquiring data for accession 362/4029..
# Acquiring data for accession 363/4029..
# Acquiring data for accession 364/4029..
# Acquiring data for accession 365/4029..
# Acquiring data for accession 366/4029..
# Acquiring data for accession 367/4029..
# Acquiring data for accession 368/4029..
# Acquiring data for accession 369/4029..
# Acquiring data for accession 370/4029..
# Acquiring data for accession 371/4029..
# Acquiring data for accession 372/4029..
# Acquiring data for accession 373/4029..
# Acquiring data for accession 374/4029..
# Acquiring data for accession 375/4029..
# Acquiring data for accession 376/4029..
# Acquiring data for accession 377/4029..
# Acquiring data for accession 378/4029..
# Acquiring data for accession 379/4029..
# Acquiring data for accession 380/4029..
# Acquiring data for accession 381/4029..
# Acquiring data for accession 382/4029..
# Acquiring data for accession 383/4029..
# Acquiring data for accession 384/4029..
# Acquiring data for accession 385/4029..
# Acquiring data for accession 386/4029..
# Acquiring data for accession 387/4029..
# Acquiring data for accession 388/4029..
# Acquiring data for accession 389/4029..
# Acquiring data for accession 390/4029..
# Acquiring data for accession 391/4029..
# Acquiring data for accession 392/4029..
# Acquiring data for accession 393/4029..
# Acquiring data for accession 394/4029..
# Acquiring data for accession 395/4029..
# Acquiring data for accession 396/4029..
# Acquiring data for accession 397/4029..
# Acquiring data for accession 398/4029..
# Acquiring data for accession 399/4029..
# Acquiring data for accession 400/4029..
# Acquiring data for accession 401/4029..
# Acquiring data for accession 402/4029..
# Acquiring data for accession 403/4029..
# Acquiring data for accession 404/4029..
# Acquiring data for accession 405/4029..
# Acquiring data for accession 406/4029..
# Acquiring data for accession 407/4029..
# Acquiring data for accession 408/4029..
# Acquiring data for accession 409/4029..
# Acquiring data for accession 410/4029..
# Acquiring data for accession 411/4029..
# Acquiring data for accession 412/4029..
# Acquiring data for accession 413/4029..
# Acquiring data for accession 414/4029..
# Acquiring data for accession 415/4029..
# Acquiring data for accession 416/4029..
# Acquiring data for accession 417/4029..
# Acquiring data for accession 418/4029..
# Acquiring data for accession 419/4029..
# Acquiring data for accession 420/4029..
# Acquiring data for accession 421/4029..
# Acquiring data for accession 422/4029..
# Acquiring data for accession 423/4029..
# Acquiring data for accession 424/4029..
# Acquiring data for accession 425/4029..
# Acquiring data for accession 426/4029..
# Acquiring data for accession 427/4029..
# Acquiring data for accession 428/4029..
# Acquiring data for accession 429/4029..
# Acquiring data for accession 430/4029..
# Acquiring data for accession 431/4029..
# Acquiring data for accession 432/4029..
# Acquiring data for accession 433/4029..
# Acquiring data for accession 434/4029..
# Acquiring data for accession 435/4029..
# Acquiring data for accession 436/4029..
# Acquiring data for accession 437/4029..
# Acquiring data for accession 438/4029..
# Acquiring data for accession 439/4029..
# Acquiring data for accession 440/4029..
# Acquiring data for accession 441/4029..
# Acquiring data for accession 442/4029..
# Acquiring data for accession 443/4029..
# Acquiring data for accession 444/4029..
# Acquiring data for accession 445/4029..
# Acquiring data for accession 446/4029..
# Acquiring data for accession 447/4029..
# Acquiring data for accession 448/4029..
# Acquiring data for accession 449/4029..
# Acquiring data for accession 450/4029..
# Acquiring data for accession 451/4029..
# Acquiring data for accession 452/4029..
# Acquiring data for accession 453/4029..
# Acquiring data for accession 454/4029..
# Acquiring data for accession 455/4029..
# Acquiring data for accession 456/4029..
# Acquiring data for accession 457/4029..
# Acquiring data for accession 458/4029..
# Acquiring data for accession 459/4029..
# Acquiring data for accession 460/4029..
# Acquiring data for accession 461/4029..
# Acquiring data for accession 462/4029..
# Acquiring data for accession 463/4029..
# Acquiring data for accession 464/4029..
# Acquiring data for accession 465/4029..
# Acquiring data for accession 466/4029..
# Acquiring data for accession 467/4029..
# Acquiring data for accession 468/4029..
# Acquiring data for accession 469/4029..
# Acquiring data for accession 470/4029..
# Acquiring data for accession 471/4029..
# Acquiring data for accession 472/4029..
# Acquiring data for accession 473/4029..
# Acquiring data for accession 474/4029..
# Acquiring data for accession 475/4029..
# Acquiring data for accession 476/4029..
# Acquiring data for accession 477/4029..
# Acquiring data for accession 478/4029..
# Acquiring data for accession 479/4029..
# Acquiring data for accession 480/4029..
# Acquiring data for accession 481/4029..
# Acquiring data for accession 482/4029..
# Acquiring data for accession 483/4029..
# Acquiring data for accession 484/4029..
# Acquiring data for accession 485/4029..
# Acquiring data for accession 486/4029..
# Acquiring data for accession 487/4029..
# Acquiring data for accession 488/4029..
# Acquiring data for accession 489/4029..
# Acquiring data for accession 490/4029..
# Acquiring data for accession 491/4029..
# Acquiring data for accession 492/4029..
# Acquiring data for accession 493/4029..
# Acquiring data for accession 494/4029..
# Acquiring data for accession 495/4029..
# Acquiring data for accession 496/4029..
# Acquiring data for accession 497/4029..
# Acquiring data for accession 498/4029..
# Acquiring data for accession 499/4029..
# Acquiring data for accession 500/4029..
# Acquiring data for accession 501/4029..
# Acquiring data for accession 502/4029..
# Acquiring data for accession 503/4029..
# Acquiring data for accession 504/4029..
# Acquiring data for accession 505/4029..
# Acquiring data for accession 506/4029..
# Acquiring data for accession 507/4029..
# Acquiring data for accession 508/4029..
# Acquiring data for accession 509/4029..
# Acquiring data for accession 510/4029..
# Acquiring data for accession 511/4029..
# Acquiring data for accession 512/4029..
# Acquiring data for accession 513/4029..
# Acquiring data for accession 514/4029..
# Acquiring data for accession 515/4029..
# Acquiring data for accession 516/4029..
# Acquiring data for accession 517/4029..
# Acquiring data for accession 518/4029..
# Acquiring data for accession 519/4029..
# Acquiring data for accession 520/4029..
# Acquiring data for accession 521/4029..
# Acquiring data for accession 522/4029..
# Acquiring data for accession 523/4029..
# Acquiring data for accession 524/4029..
# Acquiring data for accession 525/4029..
# Acquiring data for accession 526/4029..
# Acquiring data for accession 527/4029..
# Acquiring data for accession 528/4029..
# Acquiring data for accession 529/4029..
# Acquiring data for accession 530/4029..
# Acquiring data for accession 531/4029..
# Acquiring data for accession 532/4029..
# Acquiring data for accession 533/4029..
# Acquiring data for accession 534/4029..
# Acquiring data for accession 535/4029..
# Acquiring data for accession 536/4029..
# Acquiring data for accession 537/4029..
# Acquiring data for accession 538/4029..
# Acquiring data for accession 539/4029..
# Acquiring data for accession 540/4029..
# Acquiring data for accession 541/4029..
# Acquiring data for accession 542/4029..
# Acquiring data for accession 543/4029..
# Acquiring data for accession 544/4029..
# Acquiring data for accession 545/4029..
# Acquiring data for accession 546/4029..
# Acquiring data for accession 547/4029..
# Acquiring data for accession 548/4029..
# Acquiring data for accession 549/4029..
# Acquiring data for accession 550/4029..
# Acquiring data for accession 551/4029..
# Acquiring data for accession 552/4029..
# Acquiring data for accession 553/4029..
# Acquiring data for accession 554/4029..
# Acquiring data for accession 555/4029..
# Acquiring data for accession 556/4029..
# Acquiring data for accession 557/4029..
# Acquiring data for accession 558/4029..
# Acquiring data for accession 559/4029..
# Acquiring data for accession 560/4029..
# Acquiring data for accession 561/4029..
# Acquiring data for accession 562/4029..
# Acquiring data for accession 563/4029..
# Acquiring data for accession 564/4029..
# Acquiring data for accession 565/4029..
# Acquiring data for accession 566/4029..
# Acquiring data for accession 567/4029..
# Acquiring data for accession 568/4029..
# Acquiring data for accession 569/4029..
# Acquiring data for accession 570/4029..
# Acquiring data for accession 571/4029..
# Acquiring data for accession 572/4029..
# Acquiring data for accession 573/4029..
# Acquiring data for accession 574/4029..
# Acquiring data for accession 575/4029..
# Acquiring data for accession 576/4029..
# Acquiring data for accession 577/4029..
# Acquiring data for accession 578/4029..
# Acquiring data for accession 579/4029..
# Acquiring data for accession 580/4029..
# Acquiring data for accession 581/4029..
# Acquiring data for accession 582/4029..
# Acquiring data for accession 583/4029..
# Acquiring data for accession 584/4029..
# Acquiring data for accession 585/4029..
# Acquiring data for accession 586/4029..
# Acquiring data for accession 587/4029..
# Acquiring data for accession 588/4029..
# Acquiring data for accession 589/4029..
# Acquiring data for accession 590/4029..
# Acquiring data for accession 591/4029..
# Acquiring data for accession 592/4029..
# Acquiring data for accession 593/4029..
# Acquiring data for accession 594/4029..
# Acquiring data for accession 595/4029..
# Acquiring data for accession 596/4029..
# Acquiring data for accession 597/4029..
# Acquiring data for accession 598/4029..
# Acquiring data for accession 599/4029..
# Acquiring data for accession 600/4029..
# Acquiring data for accession 601/4029..
# Acquiring data for accession 602/4029..
# Acquiring data for accession 603/4029..
# Acquiring data for accession 604/4029..
# Acquiring data for accession 605/4029..
# Acquiring data for accession 606/4029..
# Acquiring data for accession 607/4029..
# Acquiring data for accession 608/4029..
# Acquiring data for accession 609/4029..
# Acquiring data for accession 610/4029..
# Acquiring data for accession 611/4029..
# Acquiring data for accession 612/4029..
# Acquiring data for accession 613/4029..
# Acquiring data for accession 614/4029..
# Acquiring data for accession 615/4029..
# Acquiring data for accession 616/4029..
# Acquiring data for accession 617/4029..
# Acquiring data for accession 618/4029..
# Acquiring data for accession 619/4029..
# Acquiring data for accession 620/4029..
# Acquiring data for accession 621/4029..
# Acquiring data for accession 622/4029..
# Acquiring data for accession 623/4029..
# Acquiring data for accession 624/4029..
# Acquiring data for accession 625/4029..
# Acquiring data for accession 626/4029..
# Acquiring data for accession 627/4029..
# Acquiring data for accession 628/4029..
# Acquiring data for accession 629/4029..
# Acquiring data for accession 630/4029..
# Acquiring data for accession 631/4029..
# Acquiring data for accession 632/4029..
# Acquiring data for accession 633/4029..
# Acquiring data for accession 634/4029..
# Acquiring data for accession 635/4029..
# Acquiring data for accession 636/4029..
# Acquiring data for accession 637/4029..
# Acquiring data for accession 638/4029..
# Acquiring data for accession 639/4029..
# Acquiring data for accession 640/4029..
# Acquiring data for accession 641/4029..
# Acquiring data for accession 642/4029..
# Acquiring data for accession 643/4029..
# Acquiring data for accession 644/4029..
# Acquiring data for accession 645/4029..
# Acquiring data for accession 646/4029..
# Acquiring data for accession 647/4029..
# Acquiring data for accession 648/4029..
# Acquiring data for accession 649/4029..
# Acquiring data for accession 650/4029..
# Acquiring data for accession 651/4029..
# Acquiring data for accession 652/4029..
# Acquiring data for accession 653/4029..
# Acquiring data for accession 654/4029..
# Acquiring data for accession 655/4029..
# Acquiring data for accession 656/4029..
# Acquiring data for accession 657/4029..
# Acquiring data for accession 658/4029..
# Acquiring data for accession 659/4029..
# Acquiring data for accession 660/4029..
# Acquiring data for accession 661/4029..
# Acquiring data for accession 662/4029..
# Acquiring data for accession 663/4029..
# Acquiring data for accession 664/4029..
# Acquiring data for accession 665/4029..
# Acquiring data for accession 666/4029..
# Acquiring data for accession 667/4029..
# Acquiring data for accession 668/4029..
# Acquiring data for accession 669/4029..
# Acquiring data for accession 670/4029..
# Acquiring data for accession 671/4029..
# Acquiring data for accession 672/4029..
# Acquiring data for accession 673/4029..
# Acquiring data for accession 674/4029..
# Acquiring data for accession 675/4029..
# Acquiring data for accession 676/4029..
# Acquiring data for accession 677/4029..
# Acquiring data for accession 678/4029..
# Acquiring data for accession 679/4029..
# Acquiring data for accession 680/4029..
# Acquiring data for accession 681/4029..
# Acquiring data for accession 682/4029..
# Acquiring data for accession 683/4029..
# Acquiring data for accession 684/4029..
# Acquiring data for accession 685/4029..
# Acquiring data for accession 686/4029..
# Acquiring data for accession 687/4029..
# Acquiring data for accession 688/4029..
# Acquiring data for accession 689/4029..
# Acquiring data for accession 690/4029..
# Acquiring data for accession 691/4029..
# Acquiring data for accession 692/4029..
# Acquiring data for accession 693/4029..
# Acquiring data for accession 694/4029..
# Acquiring data for accession 695/4029..
# Acquiring data for accession 696/4029..
# Acquiring data for accession 697/4029..
# Acquiring data for accession 698/4029..
# Acquiring data for accession 699/4029..
# Acquiring data for accession 700/4029..
# Acquiring data for accession 701/4029..
# Acquiring data for accession 702/4029..
# Acquiring data for accession 703/4029..
# Acquiring data for accession 704/4029..
# Acquiring data for accession 705/4029..
# Acquiring data for accession 706/4029..
# Acquiring data for accession 707/4029..
# Acquiring data for accession 708/4029..
# Acquiring data for accession 709/4029..
# Acquiring data for accession 710/4029..
# Acquiring data for accession 711/4029..
# Acquiring data for accession 712/4029..
# Acquiring data for accession 713/4029..
# Acquiring data for accession 714/4029..
# Acquiring data for accession 715/4029..
# Acquiring data for accession 716/4029..
# Acquiring data for accession 717/4029..
# Acquiring data for accession 718/4029..
# Acquiring data for accession 719/4029..
# Acquiring data for accession 720/4029..
# Acquiring data for accession 721/4029..
# Acquiring data for accession 722/4029..
# Acquiring data for accession 723/4029..
# Acquiring data for accession 724/4029..
# Acquiring data for accession 725/4029..
# Acquiring data for accession 726/4029..
# Acquiring data for accession 727/4029..
# Acquiring data for accession 728/4029..
# Acquiring data for accession 729/4029..
# Acquiring data for accession 730/4029..
# Acquiring data for accession 731/4029..
# Acquiring data for accession 732/4029..
# Acquiring data for accession 733/4029..
# Acquiring data for accession 734/4029..
# Acquiring data for accession 735/4029..
# Acquiring data for accession 736/4029..
# Acquiring data for accession 737/4029..
# Acquiring data for accession 738/4029..
# Acquiring data for accession 739/4029..
# Acquiring data for accession 740/4029..
# Acquiring data for accession 741/4029..
# Acquiring data for accession 742/4029..
# Acquiring data for accession 743/4029..
# Acquiring data for accession 744/4029..
# Acquiring data for accession 745/4029..
# Acquiring data for accession 746/4029..
# Acquiring data for accession 747/4029..
# Acquiring data for accession 748/4029..
# Acquiring data for accession 749/4029..
# Acquiring data for accession 750/4029..
# Acquiring data for accession 751/4029..
# Acquiring data for accession 752/4029..
# Acquiring data for accession 753/4029..
# Acquiring data for accession 754/4029..
# Acquiring data for accession 755/4029..
# Acquiring data for accession 756/4029..
# Acquiring data for accession 757/4029..
# Acquiring data for accession 758/4029..
# Acquiring data for accession 759/4029..
# Acquiring data for accession 760/4029..
# Acquiring data for accession 761/4029..
# Acquiring data for accession 762/4029..
# Acquiring data for accession 763/4029..
# Acquiring data for accession 764/4029..
# Acquiring data for accession 765/4029..
# Acquiring data for accession 766/4029..
# Acquiring data for accession 767/4029..
# Acquiring data for accession 768/4029..
# Acquiring data for accession 769/4029..
# Acquiring data for accession 770/4029..
# Acquiring data for accession 771/4029..
# Acquiring data for accession 772/4029..
# Acquiring data for accession 773/4029..
# Acquiring data for accession 774/4029..
# Acquiring data for accession 775/4029..
# Acquiring data for accession 776/4029..
# Acquiring data for accession 777/4029..
# Acquiring data for accession 778/4029..
# Acquiring data for accession 779/4029..
# Acquiring data for accession 780/4029..
# Acquiring data for accession 781/4029..
# Acquiring data for accession 782/4029..
# Acquiring data for accession 783/4029..
# Acquiring data for accession 784/4029..
# Acquiring data for accession 785/4029..
# Acquiring data for accession 786/4029..
# Acquiring data for accession 787/4029..
# Acquiring data for accession 788/4029..
# Acquiring data for accession 789/4029..
# Acquiring data for accession 790/4029..
# Acquiring data for accession 791/4029..
# Acquiring data for accession 792/4029..
# Acquiring data for accession 793/4029..
# Acquiring data for accession 794/4029..
# Acquiring data for accession 795/4029..
# Acquiring data for accession 796/4029..
# Acquiring data for accession 797/4029..
# Acquiring data for accession 798/4029..
# Acquiring data for accession 799/4029..
# Acquiring data for accession 800/4029..
# Acquiring data for accession 801/4029..
# Acquiring data for accession 802/4029..
# Acquiring data for accession 803/4029..
# Acquiring data for accession 804/4029..
# Acquiring data for accession 805/4029..
# Acquiring data for accession 806/4029..
# Acquiring data for accession 807/4029..
# Acquiring data for accession 808/4029..
# Acquiring data for accession 809/4029..
# Acquiring data for accession 810/4029..
# Acquiring data for accession 811/4029..
# Acquiring data for accession 812/4029..
# Acquiring data for accession 813/4029..
# Acquiring data for accession 814/4029..
# Acquiring data for accession 815/4029..
# Acquiring data for accession 816/4029..
# Acquiring data for accession 817/4029..
# Acquiring data for accession 818/4029..
# Acquiring data for accession 819/4029..
# Acquiring data for accession 820/4029..
# Acquiring data for accession 821/4029..
# Acquiring data for accession 822/4029..
# Acquiring data for accession 823/4029..
# Acquiring data for accession 824/4029..
# Acquiring data for accession 825/4029..
# Acquiring data for accession 826/4029..
# Acquiring data for accession 827/4029..
# Acquiring data for accession 828/4029..
# Acquiring data for accession 829/4029..
# Acquiring data for accession 830/4029..
# Acquiring data for accession 831/4029..
# Acquiring data for accession 832/4029..
# Acquiring data for accession 833/4029..
# Acquiring data for accession 834/4029..
# Acquiring data for accession 835/4029..
# Acquiring data for accession 836/4029..
# Acquiring data for accession 837/4029..
# Acquiring data for accession 838/4029..
# Acquiring data for accession 839/4029..
# Acquiring data for accession 840/4029..
# Acquiring data for accession 841/4029..
# Acquiring data for accession 842/4029..
# Acquiring data for accession 843/4029..
# Acquiring data for accession 844/4029..
# Acquiring data for accession 845/4029..
# Acquiring data for accession 846/4029..
# Acquiring data for accession 847/4029..
# Acquiring data for accession 848/4029..
# Acquiring data for accession 849/4029..
# Acquiring data for accession 850/4029..
# Acquiring data for accession 851/4029..
# Acquiring data for accession 852/4029..
# Acquiring data for accession 853/4029..
# Acquiring data for accession 854/4029..
# Acquiring data for accession 855/4029..
# Acquiring data for accession 856/4029..
# Acquiring data for accession 857/4029..
# Acquiring data for accession 858/4029..
# Acquiring data for accession 859/4029..
# Acquiring data for accession 860/4029..
# Acquiring data for accession 861/4029..
# Acquiring data for accession 862/4029..
# Acquiring data for accession 863/4029..
# Acquiring data for accession 864/4029..
# Acquiring data for accession 865/4029..
# Acquiring data for accession 866/4029..
# Acquiring data for accession 867/4029..
# Acquiring data for accession 868/4029..
# Acquiring data for accession 869/4029..
# Acquiring data for accession 870/4029..
# Acquiring data for accession 871/4029..
# Acquiring data for accession 872/4029..
# Acquiring data for accession 873/4029..
# Acquiring data for accession 874/4029..
# Acquiring data for accession 875/4029..
# Acquiring data for accession 876/4029..
# Acquiring data for accession 877/4029..
# Acquiring data for accession 878/4029..
# Acquiring data for accession 879/4029..
# Acquiring data for accession 880/4029..
# Acquiring data for accession 881/4029..
# Acquiring data for accession 882/4029..
# Acquiring data for accession 883/4029..
# Acquiring data for accession 884/4029..
# Acquiring data for accession 885/4029..
# Acquiring data for accession 886/4029..
# Acquiring data for accession 887/4029..
# Acquiring data for accession 888/4029..
# Acquiring data for accession 889/4029..
# Acquiring data for accession 890/4029..
# Acquiring data for accession 891/4029..
# Acquiring data for accession 892/4029..
# Acquiring data for accession 893/4029..
# Acquiring data for accession 894/4029..
# Acquiring data for accession 895/4029..
# Acquiring data for accession 896/4029..
# Acquiring data for accession 897/4029..
# Acquiring data for accession 898/4029..
# Acquiring data for accession 899/4029..
# Acquiring data for accession 900/4029..
# Acquiring data for accession 901/4029..
# Acquiring data for accession 902/4029..
# Acquiring data for accession 903/4029..
# Acquiring data for accession 904/4029..
# Acquiring data for accession 905/4029..
# Acquiring data for accession 906/4029..
# Acquiring data for accession 907/4029..
# Acquiring data for accession 908/4029..
# Acquiring data for accession 909/4029..
# Acquiring data for accession 910/4029..
# Acquiring data for accession 911/4029..
# Acquiring data for accession 912/4029..
# Acquiring data for accession 913/4029..
# Acquiring data for accession 914/4029..
# Acquiring data for accession 915/4029..
# Acquiring data for accession 916/4029..
# Acquiring data for accession 917/4029..
# Acquiring data for accession 918/4029..
# Acquiring data for accession 919/4029..
# Acquiring data for accession 920/4029..
# Acquiring data for accession 921/4029..
# Acquiring data for accession 922/4029..
# Acquiring data for accession 923/4029..
# Acquiring data for accession 924/4029..
# Acquiring data for accession 925/4029..
# Acquiring data for accession 926/4029..
# Acquiring data for accession 927/4029..
# Acquiring data for accession 928/4029..
# Acquiring data for accession 929/4029..
# Acquiring data for accession 930/4029..
# Acquiring data for accession 931/4029..
# Acquiring data for accession 932/4029..
# Acquiring data for accession 933/4029..
# Acquiring data for accession 934/4029..
# Acquiring data for accession 935/4029..
# Acquiring data for accession 936/4029..
# Acquiring data for accession 937/4029..
# Acquiring data for accession 938/4029..
# Acquiring data for accession 939/4029..
# Acquiring data for accession 940/4029..
# Acquiring data for accession 941/4029..
# Acquiring data for accession 942/4029..
# Acquiring data for accession 943/4029..
# Acquiring data for accession 944/4029..
# Acquiring data for accession 945/4029..
# Acquiring data for accession 946/4029..
# Acquiring data for accession 947/4029..
# Acquiring data for accession 948/4029..
# Acquiring data for accession 949/4029..
# Acquiring data for accession 950/4029..
# Acquiring data for accession 951/4029..
# Acquiring data for accession 952/4029..
# Acquiring data for accession 953/4029..
# Acquiring data for accession 954/4029..
# Acquiring data for accession 955/4029..
# Acquiring data for accession 956/4029..
# Acquiring data for accession 957/4029..
# Acquiring data for accession 958/4029..
# Acquiring data for accession 959/4029..
# Acquiring data for accession 960/4029..
# Acquiring data for accession 961/4029..
# Acquiring data for accession 962/4029..
# Acquiring data for accession 963/4029..
# Acquiring data for accession 964/4029..
# Acquiring data for accession 965/4029..
# Acquiring data for accession 966/4029..
# Acquiring data for accession 967/4029..
# Acquiring data for accession 968/4029..
# Acquiring data for accession 969/4029..
# Acquiring data for accession 970/4029..
# Acquiring data for accession 971/4029..
# Acquiring data for accession 972/4029..
# Acquiring data for accession 973/4029..
# Acquiring data for accession 974/4029..
# Acquiring data for accession 975/4029..
# Acquiring data for accession 976/4029..
# Acquiring data for accession 977/4029..
# Acquiring data for accession 978/4029..
# Acquiring data for accession 979/4029..
# Acquiring data for accession 980/4029..
# Acquiring data for accession 981/4029..
# Acquiring data for accession 982/4029..
# Acquiring data for accession 983/4029..
# Acquiring data for accession 984/4029..
# Acquiring data for accession 985/4029..
# Acquiring data for accession 986/4029..
# Acquiring data for accession 987/4029..
# Acquiring data for accession 988/4029..
# Acquiring data for accession 989/4029..
# Acquiring data for accession 990/4029..
# Acquiring data for accession 991/4029..
# Acquiring data for accession 992/4029..
# Acquiring data for accession 993/4029..
# Acquiring data for accession 994/4029..
# Acquiring data for accession 995/4029..
# Acquiring data for accession 996/4029..
# Acquiring data for accession 997/4029..
# Acquiring data for accession 998/4029..
# Acquiring data for accession 999/4029..
# Acquiring data for accession 1000/4029..
# Acquiring data for accession 1001/4029..
# Acquiring data for accession 1002/4029..
# Acquiring data for accession 1003/4029..
# Acquiring data for accession 1004/4029..
# Acquiring data for accession 1005/4029..
# Acquiring data for accession 1006/4029..
# Acquiring data for accession 1007/4029..
# Acquiring data for accession 1008/4029..
# Acquiring data for accession 1009/4029..
# Acquiring data for accession 1010/4029..
# Acquiring data for accession 1011/4029..
# Acquiring data for accession 1012/4029..
# Acquiring data for accession 1013/4029..
# Acquiring data for accession 1014/4029..
# Acquiring data for accession 1015/4029..
# Acquiring data for accession 1016/4029..
# Acquiring data for accession 1017/4029..
# Acquiring data for accession 1018/4029..
# Acquiring data for accession 1019/4029..
# Acquiring data for accession 1020/4029..
# Acquiring data for accession 1021/4029..
# Acquiring data for accession 1022/4029..
# Acquiring data for accession 1023/4029..
# Acquiring data for accession 1024/4029..
# Acquiring data for accession 1025/4029..
# Acquiring data for accession 1026/4029..
# Acquiring data for accession 1027/4029..
# Acquiring data for accession 1028/4029..
# Acquiring data for accession 1029/4029..
# Acquiring data for accession 1030/4029..
# Acquiring data for accession 1031/4029..
# Acquiring data for accession 1032/4029..
# Acquiring data for accession 1033/4029..
# Acquiring data for accession 1034/4029..
# Acquiring data for accession 1035/4029..
# Acquiring data for accession 1036/4029..
# Acquiring data for accession 1037/4029..
# Acquiring data for accession 1038/4029..
# Acquiring data for accession 1039/4029..
# Acquiring data for accession 1040/4029..
# Acquiring data for accession 1041/4029..
# Acquiring data for accession 1042/4029..
# Acquiring data for accession 1043/4029..
# Acquiring data for accession 1044/4029..
# Acquiring data for accession 1045/4029..
# Acquiring data for accession 1046/4029..
# Acquiring data for accession 1047/4029..
# Acquiring data for accession 1048/4029..
# Acquiring data for accession 1049/4029..
# Acquiring data for accession 1050/4029..
# Acquiring data for accession 1051/4029..
# Acquiring data for accession 1052/4029..
# Acquiring data for accession 1053/4029..
# Acquiring data for accession 1054/4029..
# Acquiring data for accession 1055/4029..
# Acquiring data for accession 1056/4029..
# Acquiring data for accession 1057/4029..
# Acquiring data for accession 1058/4029..
# Acquiring data for accession 1059/4029..
# Acquiring data for accession 1060/4029..
# Acquiring data for accession 1061/4029..
# Acquiring data for accession 1062/4029..
# Acquiring data for accession 1063/4029..
# Acquiring data for accession 1064/4029..
# Acquiring data for accession 1065/4029..
# Acquiring data for accession 1066/4029..
# Acquiring data for accession 1067/4029..
# Acquiring data for accession 1068/4029..
# Acquiring data for accession 1069/4029..
# Acquiring data for accession 1070/4029..
# Acquiring data for accession 1071/4029..
# Acquiring data for accession 1072/4029..
# Acquiring data for accession 1073/4029..
# Acquiring data for accession 1074/4029..
# Acquiring data for accession 1075/4029..
# Acquiring data for accession 1076/4029..
# Acquiring data for accession 1077/4029..
# Acquiring data for accession 1078/4029..
# Acquiring data for accession 1079/4029..
# Acquiring data for accession 1080/4029..
# Acquiring data for accession 1081/4029..
# Acquiring data for accession 1082/4029..
# Acquiring data for accession 1083/4029..
# Acquiring data for accession 1084/4029..
# Acquiring data for accession 1085/4029..
# Acquiring data for accession 1086/4029..
# Acquiring data for accession 1087/4029..
# Acquiring data for accession 1088/4029..
# Acquiring data for accession 1089/4029..
# Acquiring data for accession 1090/4029..
# Acquiring data for accession 1091/4029..
# Acquiring data for accession 1092/4029..
# Acquiring data for accession 1093/4029..
# Acquiring data for accession 1094/4029..
# Acquiring data for accession 1095/4029..
# Acquiring data for accession 1096/4029..
# Acquiring data for accession 1097/4029..
# Acquiring data for accession 1098/4029..
# Acquiring data for accession 1099/4029..
# Acquiring data for accession 1100/4029..
# Acquiring data for accession 1101/4029..
# Acquiring data for accession 1102/4029..
# Acquiring data for accession 1103/4029..
# Acquiring data for accession 1104/4029..
# Acquiring data for accession 1105/4029..
# Acquiring data for accession 1106/4029..
# Acquiring data for accession 1107/4029..
# Acquiring data for accession 1108/4029..
# Acquiring data for accession 1109/4029..
# Acquiring data for accession 1110/4029..
# Acquiring data for accession 1111/4029..
# Acquiring data for accession 1112/4029..
# Acquiring data for accession 1113/4029..
# Acquiring data for accession 1114/4029..
# Acquiring data for accession 1115/4029..
# Acquiring data for accession 1116/4029..
# Acquiring data for accession 1117/4029..
# Acquiring data for accession 1118/4029..
# Acquiring data for accession 1119/4029..
# Acquiring data for accession 1120/4029..
# Acquiring data for accession 1121/4029..
# Acquiring data for accession 1122/4029..
# Acquiring data for accession 1123/4029..
# Acquiring data for accession 1124/4029..
# Acquiring data for accession 1125/4029..
# Acquiring data for accession 1126/4029..
# Acquiring data for accession 1127/4029..
# Acquiring data for accession 1128/4029..
# Acquiring data for accession 1129/4029..
# Acquiring data for accession 1130/4029..
# Acquiring data for accession 1131/4029..
# Acquiring data for accession 1132/4029..
# Acquiring data for accession 1133/4029..
# Acquiring data for accession 1134/4029..
# Acquiring data for accession 1135/4029..
# Acquiring data for accession 1136/4029..
# Acquiring data for accession 1137/4029..
# Acquiring data for accession 1138/4029..
# Acquiring data for accession 1139/4029..
# Acquiring data for accession 1140/4029..
# Acquiring data for accession 1141/4029..
# Acquiring data for accession 1142/4029..
# Acquiring data for accession 1143/4029..
# Acquiring data for accession 1144/4029..
# Acquiring data for accession 1145/4029..
# Acquiring data for accession 1146/4029..
# Acquiring data for accession 1147/4029..
# Acquiring data for accession 1148/4029..
# Acquiring data for accession 1149/4029..
# Acquiring data for accession 1150/4029..
# Acquiring data for accession 1151/4029..
# Acquiring data for accession 1152/4029..
# Acquiring data for accession 1153/4029..
# Acquiring data for accession 1154/4029..
# Acquiring data for accession 1155/4029..
# Acquiring data for accession 1156/4029..
# Acquiring data for accession 1157/4029..
# Acquiring data for accession 1158/4029..
# Acquiring data for accession 1159/4029..
# Acquiring data for accession 1160/4029..
# Acquiring data for accession 1161/4029..
# Acquiring data for accession 1162/4029..
# Acquiring data for accession 1163/4029..
# Acquiring data for accession 1164/4029..
# Acquiring data for accession 1165/4029..
# Acquiring data for accession 1166/4029..
# Acquiring data for accession 1167/4029..
# Acquiring data for accession 1168/4029..
# Acquiring data for accession 1169/4029..
# Acquiring data for accession 1170/4029..
# Acquiring data for accession 1171/4029..
# Acquiring data for accession 1172/4029..
# Acquiring data for accession 1173/4029..
# Acquiring data for accession 1174/4029..
# Acquiring data for accession 1175/4029..
# Acquiring data for accession 1176/4029..
# Acquiring data for accession 1177/4029..
# Acquiring data for accession 1178/4029..
# Acquiring data for accession 1179/4029..
# Acquiring data for accession 1180/4029..
# Acquiring data for accession 1181/4029..
# Acquiring data for accession 1182/4029..
# Acquiring data for accession 1183/4029..
# Acquiring data for accession 1184/4029..
# Acquiring data for accession 1185/4029..
# Acquiring data for accession 1186/4029..
# Acquiring data for accession 1187/4029..
# Acquiring data for accession 1188/4029..
# Acquiring data for accession 1189/4029..
# Acquiring data for accession 1190/4029..
# Acquiring data for accession 1191/4029..
# Acquiring data for accession 1192/4029..
# Acquiring data for accession 1193/4029..
# Acquiring data for accession 1194/4029..
# Acquiring data for accession 1195/4029..
# Acquiring data for accession 1196/4029..
# ...
# Acquiring data for accession 3764/4029..
# Acquiring data for accession 3765/4029..
# Acquiring data for accession 3766/4029..
# Acquiring data for accession 3767/4029..
# Acquiring data for accession 3768/4029..
# Acquiring data for accession 3769/4029..
# Acquiring data for accession 3770/4029..
# Acquiring data for accession 3771/4029..
# Acquiring data for accession 3772/4029..
# Acquiring data for accession 3773/4029..
# Acquiring data for accession 3774/4029..
# Acquiring data for accession 3775/4029..
# Acquiring data for accession 3776/4029..
# Acquiring data for accession 3777/4029..
# Acquiring data for accession 3778/4029..
# Acquiring data for accession 3779/4029..
# Acquiring data for accession 3780/4029..
# Acquiring data for accession 3781/4029..
# Acquiring data for accession 3782/4029..
# Acquiring data for accession 3783/4029..
# Acquiring data for accession 3784/4029..
# Acquiring data for accession 3785/4029..
# Acquiring data for accession 3786/4029..
# Acquiring data for accession 3787/4029..
# Acquiring data for accession 3788/4029..
# Acquiring data for accession 3789/4029..
# Acquiring data for accession 3790/4029..
# Acquiring data for accession 3791/4029..
# Acquiring data for accession 3792/4029..
# Acquiring data for accession 3793/4029..
# Acquiring data for accession 3794/4029..
# Acquiring data for accession 3795/4029..
# Acquiring data for accession 3796/4029..
# Acquiring data for accession 3797/4029..
# Acquiring data for accession 3798/4029..
# Acquiring data for accession 3799/4029..
# Acquiring data for accession 3800/4029..
# Acquiring data for accession 3801/4029..
# Acquiring data for accession 3802/4029..
# Acquiring data for accession 3803/4029..
# Acquiring data for accession 3804/4029..
# Acquiring data for accession 3805/4029..
# Acquiring data for accession 3806/4029..
# Acquiring data for accession 3807/4029..
# Acquiring data for accession 3808/4029..
# Acquiring data for accession 3809/4029..
# Acquiring data for accession 3810/4029..
# Acquiring data for accession 3811/4029..
# Acquiring data for accession 3812/4029..
# Acquiring data for accession 3813/4029..
# Acquiring data for accession 3814/4029..
# Acquiring data for accession 3815/4029..
# Acquiring data for accession 3816/4029..
# Acquiring data for accession 3817/4029..
# Acquiring data for accession 3818/4029..
# Acquiring data for accession 3819/4029..
# Acquiring data for accession 3820/4029..
# Acquiring data for accession 3821/4029..
# Acquiring data for accession 3822/4029..
# Acquiring data for accession 3823/4029..
# Acquiring data for accession 3824/4029..
# Acquiring data for accession 3825/4029..
# Acquiring data for accession 3826/4029..
# Acquiring data for accession 3827/4029..
# Acquiring data for accession 3828/4029..
# Acquiring data for accession 3829/4029..
# Acquiring data for accession 3830/4029..
# Acquiring data for accession 3831/4029..
# Acquiring data for accession 3832/4029..
# Acquiring data for accession 3833/4029..
# Acquiring data for accession 3834/4029..
# Acquiring data for accession 3835/4029..
# Acquiring data for accession 3836/4029..
# Acquiring data for accession 3837/4029..
# Acquiring data for accession 3838/4029..
# Acquiring data for accession 3839/4029..
# Acquiring data for accession 3840/4029..
# Acquiring data for accession 3841/4029..
# Acquiring data for accession 3842/4029..
# Acquiring data for accession 3843/4029..
# Acquiring data for accession 3844/4029..
# Acquiring data for accession 3845/4029..
# Acquiring data for accession 3846/4029..
# Acquiring data for accession 3847/4029..
# Acquiring data for accession 3848/4029..
# Acquiring data for accession 3849/4029..
# Acquiring data for accession 3850/4029..
# Acquiring data for accession 3851/4029..
# Acquiring data for accession 3852/4029..
# Acquiring data for accession 3853/4029..
# Acquiring data for accession 3854/4029..
# Acquiring data for accession 3855/4029..
# Acquiring data for accession 3856/4029..
# Acquiring data for accession 3857/4029..
# Acquiring data for accession 3858/4029..
# Acquiring data for accession 3859/4029..
# Acquiring data for accession 3860/4029..
# Acquiring data for accession 3861/4029..
# Acquiring data for accession 3862/4029..
# Acquiring data for accession 3863/4029..
# Acquiring data for accession 3864/4029..
# Acquiring data for accession 3865/4029..
# Acquiring data for accession 3866/4029..
# Acquiring data for accession 3867/4029..
# Acquiring data for accession 3868/4029..
# Acquiring data for accession 3869/4029..
# Acquiring data for accession 3870/4029..
# Acquiring data for accession 3871/4029..
# Acquiring data for accession 3872/4029..
# Acquiring data for accession 3873/4029..
# Acquiring data for accession 3874/4029..
# Acquiring data for accession 3875/4029..
# Acquiring data for accession 3876/4029..
# Acquiring data for accession 3877/4029..
# Acquiring data for accession 3878/4029..
# Acquiring data for accession 3879/4029..
# Acquiring data for accession 3880/4029..
# Acquiring data for accession 3881/4029..
# Acquiring data for accession 3882/4029..
# Acquiring data for accession 3883/4029..
# Acquiring data for accession 3884/4029..
# Acquiring data for accession 3885/4029..
# Acquiring data for accession 3886/4029..
# Acquiring data for accession 3887/4029..
# Acquiring data for accession 3888/4029..
# Acquiring data for accession 3889/4029..
# Acquiring data for accession 3890/4029..
# Acquiring data for accession 3891/4029..
# Acquiring data for accession 3892/4029..
# Acquiring data for accession 3893/4029..
# Acquiring data for accession 3894/4029..
# Acquiring data for accession 3895/4029..
# Acquiring data for accession 3896/4029..
# Acquiring data for accession 3897/4029..
# Acquiring data for accession 3898/4029..
# Acquiring data for accession 3899/4029..
# Acquiring data for accession 3900/4029..
# Acquiring data for accession 3901/4029..
# Acquiring data for accession 3902/4029..
# Acquiring data for accession 3903/4029..
# Acquiring data for accession 3904/4029..
# Acquiring data for accession 3905/4029..
# Acquiring data for accession 3906/4029..
# Acquiring data for accession 3907/4029..
# Acquiring data for accession 3908/4029..
# Acquiring data for accession 3909/4029..
# Acquiring data for accession 3910/4029..
# Acquiring data for accession 3911/4029..
# Acquiring data for accession 3912/4029..
# Acquiring data for accession 3913/4029..
# Acquiring data for accession 3914/4029..
# Acquiring data for accession 3915/4029..
# Acquiring data for accession 3916/4029..
# Acquiring data for accession 3917/4029..
# Acquiring data for accession 3918/4029..
# Acquiring data for accession 3919/4029..
# Acquiring data for accession 3920/4029..
# Acquiring data for accession 3921/4029..
# Acquiring data for accession 3922/4029..
# Acquiring data for accession 3923/4029..
# Acquiring data for accession 3924/4029..
# Acquiring data for accession 3925/4029..
# Acquiring data for accession 3926/4029..
# Acquiring data for accession 3927/4029..
# Acquiring data for accession 3928/4029..
# Acquiring data for accession 3929/4029..
# Acquiring data for accession 3930/4029..
# Acquiring data for accession 3931/4029..
# Acquiring data for accession 3932/4029..
# Acquiring data for accession 3933/4029..
# Acquiring data for accession 3934/4029..
# Acquiring data for accession 3935/4029..
# Acquiring data for accession 3936/4029..
# Acquiring data for accession 3937/4029..
# Acquiring data for accession 3938/4029..
# Acquiring data for accession 3939/4029..
# Acquiring data for accession 3940/4029..
# Acquiring data for accession 3941/4029..
# Acquiring data for accession 3942/4029..
# Acquiring data for accession 3943/4029..
# Acquiring data for accession 3944/4029..
# Acquiring data for accession 3945/4029..
# Acquiring data for accession 3946/4029..
# Acquiring data for accession 3947/4029..
# Acquiring data for accession 3948/4029..
# Acquiring data for accession 3949/4029..
# Acquiring data for accession 3950/4029..
# Acquiring data for accession 3951/4029..
# Acquiring data for accession 3952/4029..
# Acquiring data for accession 3953/4029..
# Acquiring data for accession 3954/4029..
# Acquiring data for accession 3955/4029..
# Acquiring data for accession 3956/4029..
# Acquiring data for accession 3957/4029..
# Acquiring data for accession 3958/4029..
# Acquiring data for accession 3959/4029..
# Acquiring data for accession 3960/4029..
# Acquiring data for accession 3961/4029..
# Acquiring data for accession 3962/4029..
# Acquiring data for accession 3963/4029..
# Acquiring data for accession 3964/4029..
# Acquiring data for accession 3965/4029..
# Acquiring data for accession 3966/4029..
# Acquiring data for accession 3967/4029..
# Acquiring data for accession 3968/4029..
# Acquiring data for accession 3969/4029..
# Acquiring data for accession 3970/4029..
# Acquiring data for accession 3971/4029..
# Acquiring data for accession 3972/4029..
# Acquiring data for accession 3973/4029..
# Acquiring data for accession 3974/4029..
# Acquiring data for accession 3975/4029..
# Acquiring data for accession 3976/4029..
# Acquiring data for accession 3977/4029..
# Acquiring data for accession 3978/4029..
# Acquiring data for accession 3979/4029..
# Acquiring data for accession 3980/4029..
# Acquiring data for accession 3981/4029..
# Acquiring data for accession 3982/4029..
# Acquiring data for accession 3983/4029..
# Acquiring data for accession 3984/4029..
# Acquiring data for accession 3985/4029..
# Acquiring data for accession 3986/4029..
# Acquiring data for accession 3987/4029..
# Acquiring data for accession 3988/4029..
# Acquiring data for accession 3989/4029..
# Acquiring data for accession 3990/4029..
# Acquiring data for accession 3991/4029..
# Acquiring data for accession 3992/4029..
# Acquiring data for accession 3993/4029..
# Acquiring data for accession 3994/4029..
# Acquiring data for accession 3995/4029..
# Acquiring data for accession 3996/4029..
# Acquiring data for accession 3997/4029..
# Acquiring data for accession 3998/4029..
# Acquiring data for accession 3999/4029..
# Acquiring data for accession 4000/4029..
# Acquiring data for accession 4001/4029..
# Acquiring data for accession 4002/4029..
# Acquiring data for accession 4003/4029..
# Acquiring data for accession 4004/4029..
# Acquiring data for accession 4005/4029..
# Acquiring data for accession 4006/4029..
# Acquiring data for accession 4007/4029..
# Acquiring data for accession 4008/4029..
# Acquiring data for accession 4009/4029..
# Acquiring data for accession 4010/4029..
# Acquiring data for accession 4011/4029..
# Acquiring data for accession 4012/4029..
# Acquiring data for accession 4013/4029..
# Acquiring data for accession 4014/4029..
# Acquiring data for accession 4015/4029..
# Acquiring data for accession 4016/4029..
# Acquiring data for accession 4017/4029..
# Acquiring data for accession 4018/4029..
# Acquiring data for accession 4019/4029..
# Acquiring data for accession 4020/4029..
# Acquiring data for accession 4021/4029..
# Acquiring data for accession 4022/4029..
# Acquiring data for accession 4023/4029..
# Acquiring data for accession 4024/4029..
# Acquiring data for accession 4025/4029..
# Acquiring data for accession 4026/4029..
# Acquiring data for accession 4027/4029..
# Acquiring data for accession 4028/4029..
# Acquiring data for accession 4029/4029..
# [Parallel(n_jobs=1)]: Done 4029 out of 4029 | elapsed:   16.7s finished
# Computing selected features for PPIs...
# [Parallel(n_jobs=1)]: Done   0 out of   0 | elapsed:    0.0s finished
# Updating instance attributes...
# [Parallel(n_jobs=1)]: Done   0 out of   0 | elapsed:    0.0s finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-237fafbf9bff> in <module>()
#      15         X_train = annotation_ex.transform(X_train_ppis)
# ---> 16         X_test = annotation_ex.transform(X_test_ppis)
#      17     except ValueError:
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pyppi-0.1-py3.5.egg\pyppi\data_mining\features.py in transform(self, X)
#     250             raise ValueError(
# --> 251                 "Encountered new ppis {}. Please re-fit.".format(new_ppis)
#     252             )
#
# ValueError: Encountered new ppis {PPI(P0DP23, P0DP23)}. Please re-fit.
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'accession'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-237fafbf9bff> in <module>()
#      16         X_test = annotation_ex.transform(X_test_ppis)
#      17     except ValueError:
# ---> 18         annotation_ex.fit(X_train_ppis + X_test_ppis)
#      19         X_train = annotation_ex.transform(X_train_ppis)
#      20         X_test = annotation_ex.transform(X_test_ppis)
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pyppi-0.1-py3.5.egg\pyppi\data_mining\features.py in fit(self, X, y)
#     199         for df in dfs:
#     200             self._update(df)
# --> 201         self._build_ppi_idx_map()
#     202         return self
#     203
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pyppi-0.1-py3.5.egg\pyppi\data_mining\features.py in _build_ppi_idx_map(self)
#     464
#     465     def _build_ppi_idx_map(self):
# --> 466         ppi_acc = self._ppi_df[_ACCESSION_COLUMN].values
#     467         ppi_index = self._ppi_df.index
#     468         self.ppi_idx_map = {ppi: idx for (ppi, idx) in zip(ppi_acc, ppi_index)}
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\ProgramData\Anaconda3\envs\pyppi\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5280)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5126)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20523)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20477)()
#
# KeyError: 'accession'

# %%
annotation_ex._ppi_df
# Out:
# Index([], dtype='object')

# %%
# Make the estimators and BR classifier
# -------------------------------------------------------------------- #
if retrain or not os.path.isfile(classifier_path):
    logger.info("Making classifier...")
    params = get_parameter_distribution_for_model(model)
    random_cv = RandomizedSearchCV(
        cv=n_splits,
        n_iter=rcv_iter,
        n_jobs=n_jobs,
        refit=True, 
        random_state=0,
        scoring='f1', 
        error_score=0,
        param_distributions=params,
        estimator=make_classifier(model)
    )
    clf = OneVsRestClassifier(estimator=random_cv, n_jobs=1)

    # Fit the complete training data and make predictions.
    logging.info("Fitting data...")
    clf.fit(X_train, y_train)
    joblib.dump(clf, classifier_path)

# %%
# Loads a previously (or recently trained) classifier from disk
# and then performs the predictions on the new dataset.
# -------------------------------------------------------------------- #
logging.info("Making predictions...")
clf = joblib.load(classifier_path)
predictions = clf.predict_proba(X_test)

# %%
# Write the predictions to a tsv file
# -------------------------------------------------------------------- #
logging.info("Writing results to file...")
header = "{p1}\t{p2}\t{g1}\t{g2}\t{classes}\tsum\n".format(
    p1=P1, p2=P2, g1=G1, g2=G2, classes='\t'.join(sorted(mlb.classes_))
)
out_file.write(header)
acc = annotation_ex.accession_vocabulary[UniProt.accession_column()]
genes = annotation_ex.accession_vocabulary[UniProt.data_types().GENE.value]
accession_gene_map = {a: g for (a, g) in zip(acc, genes)}
for (s, t), p_vec in zip(X_test_ppis, predictions):
    p_vec = [p for _, p in sorted(zip(mlb.classes_, p_vec))]
    g1 = accession_gene_map.get(s, ['-'])[0] or '-'
    g2 = accession_gene_map.get(t, ['-'])[0] or '-'

    # Compute the usability of each of the annotation sets
    annots = annotation_ex.transform([s, t])
    go = set([
        g.strip() for gs in annots
        for g in x.split(',')
        if 'go' in g.strip().lower()
    ])
    pf = set([
        g.strip() for gs in annots
        for g in x.split(',')
        if 'pf' in g.strip().lower()
    ])
    ipr = set([
        g.strip() for gs in annots
        for g in x.split(',')
        if 'ipr' in g.strip().lower()
    ])
    usability_go = (go & training_go) / (go | training_go)
    usability_pf = (pf & training_pfam) / (pf | training_pfam)
    usability_ipr = (ipr & training_ipr) / (ipr | training_ipr)

    sum_pr = sum(p_vec)
    line = "{s}\t{t}\t{g1}\t{g2}\t{classes}\t{sum_pr}\t{usability_go}" \
           "\t{usability_pf}\t{usability_ipr}\n".format(
            s=s, t=t, g1=g1, g2=g2, sum_pr=sum_pr,
            classes='\t'.join(['%.4f' % p for p in p_vec]),
            usability_go=usability_go,
            usability_pf=usability_pf,
            usability_ipr=usability_ipr)
    out_file.write(line)
out_file.close()
