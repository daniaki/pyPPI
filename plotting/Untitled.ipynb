# %%
from pyppi.data_mining.kegg import pathways_to_dataframe

# %%
mapk = pathways_to_dataframe(
    pathway_ids=['hsa04010'],
    drop_nan=True, 
    allow_self_edges=True,
    allow_duplicates=False, 
    min_label_count=None,
    map_to_uniprot=True, 
    trembl=False, 
    merge=True,
    verbose=False
)

# %%
mapk
# Out:
#       source  target                         label
# 0     P21781  P29317                    activation
# 1     Q13233  Q9Y6K9               phosphorylation
# 2     O43921  P00533                    activation
# 3     P10301  Q15283                    inhibition
# 4     P15692  Q02763                    activation
# 5     P06213  P10767                    activation
# 6     P35916  P61328                    activation
# 7     P01137  P37173                    activation
# 8     P27361  Q86XP0               phosphorylation
# 9     P08069  P09603                    activation
# 10    P08581  P21781                    activation
# 11    O76093  P10721                    activation
# 12    P00533  P62993           binding/association
# 13    P14210  P17948                    activation
# 14    P01135  P35916                    activation
# 15    P16234  Q9HCT0                    activation
# 16    P01133  P08069                    activation
# ...
